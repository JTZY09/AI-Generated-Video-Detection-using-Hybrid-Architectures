# %% [markdown]
# Extract 60 Frames from Face Forensics and Pika Dataset

# %%
import cv2
import os
from pathlib import Path
import numpy as np
import glob
import random
import time
import shutil

def extract_fixed_frames_from_video(video_path, output_dir, num_frames_to_extract=60, frame_prefix="frame"):
    """
    Extracts a fixed number of evenly spaced frames from a video.
    Skips if video is too short or if all frames already exist.
    """
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)
    base_name = video_path.stem

    # Check if all frames for this video already exist to skip quickly
    expected_frames = [output_dir / f"{base_name}_{frame_prefix}{i:03d}.jpg" for i in range(num_frames_to_extract)]
    if all(f.exists() for f in expected_frames):
        # print(f"[SKIP] {base_name}: All {num_frames_to_extract} frames already exist.")
        return True # Indicate success / already done

    try:
        cap = cv2.VideoCapture(str(video_path))
        if not cap.isOpened():
            print(f"[ERROR] {base_name}: Could not open video.")
            return False
        total_frames_in_video = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    except Exception as e:
        print(f"[ERROR] {base_name}: Error opening video: {e}")
        if 'cap' in locals() and cap.isOpened(): cap.release()
        return False

    if total_frames_in_video < num_frames_to_extract:
        cap.release()
        print(f"[SKIP] {video_path.name}: Too short ({total_frames_in_video} frames) for {num_frames_to_extract} required.")
        return False

    frame_indices = np.linspace(0, total_frames_in_video - 1, num_frames_to_extract, dtype=int)
    for i, frame_idx in enumerate(frame_indices):
        frame_filename = f"{base_name}_{frame_prefix}{i:03d}.jpg" # Use 3-digit padding for up to 999 frames/video
        out_path = output_dir / frame_filename

        # This inner check is for resuming a partially extracted video
        if out_path.exists():
            continue

        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)
        ret, frame = cap.read()
        if ret:
            try:
                cv2.imwrite(str(out_path), frame)
            except Exception as e_write:
                print(f"  [ERROR] Could not write frame {frame_filename}: {e_write}")
                # Don't continue if we can't write, might be a disk issue
                cap.release()
                return False

    print(f"  Extracted frames for {base_name}")
    cap.release()
    return True

# === Main Execution Block ===


# === PATHS ===
real_youtube_dir = Path("/content/drive/MyDrive/Faceforensics/FaceForensics++/original_sequences/youtube/c23/videos")
real_actors_dir = Path("/content/drive/MyDrive/Faceforensics/FaceForensics++/original_sequences/actors/c23/videos")
fake_dir = Path("/content/drive/MyDrive/pika_dataset")

# === VIDEO FILES ===
print("Gathering source video paths...")
real_videos = list(real_youtube_dir.glob("*.mp4")) + list(real_actors_dir.glob("*.mp4"))
fake_videos = list(fake_dir.glob("*.mp4"))
print(f"Found {len(real_videos)} real videos and {len(fake_videos)} fake videos.")

# === OUTPUT DIRECTORIES ===
# Use new, clear names for this extraction strategy
real_output_dir = Path("/content/drive/MyDrive/final_balanced_data/real_frames")
fake_output_dir = Path("/content/drive/MyDrive/final_balanced_data/fake_frames")
real_output_dir.mkdir(parents=True, exist_ok=True)
fake_output_dir.mkdir(parents=True, exist_ok=True)

# === CONFIGURATION FOR EXTRACTION ===
NUM_FRAMES_TO_EXTRACT_PER_VIDEO = 60 # A much more representative number

# === STEP 1: Balance by number of videos, then extract ===
print("\n--- Balancing by number of source videos ---")
num_real_videos = len(real_videos)
num_fake_videos = len(fake_videos)

if num_real_videos == 0 or num_fake_videos == 0:
    print("One of the video sources is empty. Cannot balance. Exiting.")
    exit()

min_video_count = min(num_real_videos, num_fake_videos)
print(f"Balancing to {min_video_count} videos per class.")

# Randomly sample from the larger set to match the smaller set
if num_real_videos > min_video_count:
    real_videos_sampled = random.sample(real_videos, min_video_count)
else:
    real_videos_sampled = real_videos

if num_fake_videos > min_video_count:
    fake_videos_sampled = random.sample(fake_videos, min_video_count)
else:
    fake_videos_sampled = fake_videos

print(f"Final video counts for processing: Real={len(real_videos_sampled)}, Fake={len(fake_videos_sampled)}")

# === STEP 2: Extract frames from the balanced video lists ===
print("\n--- Starting REAL frame extraction ---")
real_videos_processed = 0
for i, video_path in enumerate(real_videos_sampled):
    print(f"Processing real video {i+1}/{len(real_videos_sampled)}: {video_path.name}")
    success = extract_fixed_frames_from_video(video_path, real_output_dir, NUM_FRAMES_TO_EXTRACT_PER_VIDEO, "frame")
    if success:
        real_videos_processed += 1

print("\n--- Starting FAKE frame extraction ---")
fake_videos_processed = 0
for i, video_path in enumerate(fake_videos_sampled):
    print(f"Processing fake video {i+1}/{len(fake_videos_sampled)}: {video_path.name}")
    success = extract_fixed_frames_from_video(video_path, fake_output_dir, NUM_FRAMES_TO_EXTRACT_PER_VIDEO, "f")
    if success:
        fake_videos_processed += 1

# === Final Summary ===
print("\n--- Frame Extraction Summary ---")
final_real_frame_count = len(list(real_output_dir.glob('*.jpg')))
final_fake_frame_count = len(list(fake_output_dir.glob('*.jpg')))

print(f"Total REAL videos successfully processed: {real_videos_processed}/{len(real_videos_sampled)}")
print(f"Total REAL frames in {real_output_dir}: {final_real_frame_count}")
print("---")
print(f"Total FAKE videos successfully processed: {fake_videos_processed}/{len(fake_videos_sampled)}")
print(f"Total FAKE frames in {fake_output_dir}: {final_fake_frame_count}")
print("Extraction process complete.")
# Out:
# Gathering source video paths...

# %% [markdown]
# New Fake datasst downlaod, extract and zip

# %%
# === SCRIPT TO PROCESS, CHUNK, AND ADD-ON FRAMES MODEL-BY-MODEL ===

import os
import glob
import time
import shutil
import cv2
import numpy as np
import zipfile
import re
import math
from pathlib import Path
from google.colab import drive

# --- Configuration ---
DRIVE_SOURCE_ZIPS_DIR = "/content/drive/MyDrive/Cloned_DeepAction_Models_Zipped"
MODELS_TO_PROCESS = ["StableDiffusion.zip", "RunwayML.zip","Veo.zip","VideoPoet"]
DRIVE_OUTPUT_DIR = "/content/drive/MyDrive/zipped"
NUM_FRAMES_TO_EXTRACT = 60
CHUNK_SIZE = 10000

# --- Temporary Local Directories ---
LOCAL_TEMP_ZIPS_DIR = "/content/temp_source_zips"
LOCAL_TEMP_UNZIPPED_DIR = "/content/temp_unzipped_models"
LOCAL_EXTRACTED_FRAMES_DIR = "/content/temp_extracted_frames"

# --- Helper Function (Same as before) ---
def extract_evenly_spaced_frames(video_path, num_frames, output_folder, model_prefix, base_video_dir):
    try:
        cap = cv2.VideoCapture(str(video_path))
        if not cap.isOpened(): return
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        if total_frames < num_frames: return
        frame_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)
        relative_path = Path(video_path).relative_to(base_video_dir)
        unique_suffix = "_".join(relative_path.parts).replace('.mp4', '')
        frame_prefix = f"{model_prefix}_{unique_suffix}"
        for i, frame_idx in enumerate(frame_indices):
            cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)
            ret, frame = cap.read()
            if ret:
                output_filename = f"{frame_prefix}_frame_{i:03d}.jpg"
                output_path = os.path.join(output_folder, output_filename)
                cv2.imwrite(output_path, frame)
    finally:
        if 'cap' in locals() and cap.isOpened(): cap.release()

# --- Main Logic ---
if __name__ == '__main__':
    print("--- Starting Model-by-Model Frame Extraction and Add-On Chunking ---")
    drive.mount('/content/drive', force_remount=True)

    # --- Setup ---
    os.makedirs(DRIVE_OUTPUT_DIR, exist_ok=True)
    os.makedirs(LOCAL_TEMP_ZIPS_DIR, exist_ok=True)

    # --- Step 1: Bulk Copy source zips ---
    print("\n--- Step 1: Copying all source zips from Drive... ---")
    for zip_name in MODELS_TO_PROCESS:
        source_path = os.path.join(DRIVE_SOURCE_ZIPS_DIR, zip_name)
        if os.path.exists(source_path) and not os.path.exists(os.path.join(LOCAL_TEMP_ZIPS_DIR, zip_name)):
            shutil.copy(source_path, LOCAL_TEMP_ZIPS_DIR)

    # --- Step 2: Process each model completely, one at a time ---
    for zip_name in MODELS_TO_PROCESS:
        model_name = Path(zip_name).stem
        print(f"\n\n{'='*20} PROCESSING MODEL: {model_name.upper()} {'='*20}")
        local_zip_path = os.path.join(LOCAL_TEMP_ZIPS_DIR, zip_name)

        # --- A. Extract frames for the current model ---
        print(f"\n  A) Extracting frames for {model_name}...")

        temp_unzip_target = os.path.join(LOCAL_TEMP_UNZIPPED_DIR, model_name)
        temp_extract_target = os.path.join(LOCAL_EXTRACTED_FRAMES_DIR, model_name)
        shutil.rmtree(temp_unzip_target, ignore_errors=True)
        shutil.rmtree(temp_extract_target, ignore_errors=True)
        os.makedirs(temp_unzip_target)
        os.makedirs(temp_extract_target)

        # !unzip -q -o "{local_zip_path}" -d "{temp_unzip_target}"

        video_files = glob.glob(os.path.join(temp_unzip_target, '**', '*.mp4'), recursive=True)
        print(f"    Found {len(video_files)} videos. Starting frame extraction...")
        for i, video_path in enumerate(video_files):
            extract_evenly_spaced_frames(video_path, NUM_FRAMES_TO_EXTRACT, temp_extract_target, model_name, base_video_dir=temp_unzip_target)

        all_new_frame_paths = sorted(glob.glob(os.path.join(temp_extract_target, "*.jpg")))
        total_new_frames = len(all_new_frame_paths)
        if total_new_frames == 0:
            print(f"    WARNING: No frames extracted for {model_name}. Skipping.")
            continue
        print(f"    -> Extracted {total_new_frames:,} frames for this model.")

        # --- B. Determine Starting Point for chunking ---
        print("\n  B) Determining chunking start point from Drive...")
        existing_fake_chunks = sorted(glob.glob(os.path.join(DRIVE_OUTPUT_DIR, "fake_frames_chunk_*.zip")))
        start_chunk_num = 1
        start_file_index = 0
        if existing_fake_chunks:
            last_chunk_filename = Path(existing_fake_chunks[-1]).name
            match = re.search(r'chunk_(\d+)_(\d+)-(\d+)\.zip', last_chunk_filename)
            if match:
                last_chunk_num, _, last_file_index = map(int, match.groups())
                start_chunk_num = last_chunk_num + 1
                start_file_index = last_file_index + 1
        print(f"    -> Will start with NEW Chunk #{start_chunk_num}, indexing from file #{start_file_index}.")

        # --- C. Zip frames and upload chunks ---
        total_chunks_for_this_model = math.ceil(total_new_frames / CHUNK_SIZE)
        print(f"\n  C) Zipping and uploading {total_chunks_for_this_model} new chunk(s)...")

        for i in range(total_chunks_for_this_model):
            current_chunk_num = start_chunk_num + i
            start_slice = i * CHUNK_SIZE
            chunk_of_paths = all_new_frame_paths[start_slice : start_slice + CHUNK_SIZE]
            current_start_idx = start_file_index + (i * CHUNK_SIZE)
            current_end_idx = current_start_idx + len(chunk_of_paths) - 1
            final_zip_name = f"fake_frames_chunk_{current_chunk_num:02d}_{current_start_idx:06d}-{current_end_idx:06d}.zip"
            final_zip_path_on_drive = os.path.join(DRIVE_OUTPUT_DIR, final_zip_name)

            print(f"    --- Processing NEW FAKE Chunk #{current_chunk_num}: {final_zip_name} ---")
            if os.path.exists(final_zip_path_on_drive):
                print(f"    ✅ SKIPPING: Chunk already exists on Google Drive.")
                continue

            LOCAL_TEMP_CHUNK_DIR = f"/content/temp_chunk_{current_chunk_num}"
            os.makedirs(LOCAL_TEMP_CHUNK_DIR, exist_ok=True)
            for frame_path in chunk_of_paths:
                shutil.copy(frame_path, LOCAL_TEMP_CHUNK_DIR)
            local_zip_path = f"/content/{final_zip_name}"
            # !zip -r -q -j "{local_zip_path}" "{LOCAL_TEMP_CHUNK_DIR}/"
            # !mv "{local_zip_path}" "{final_zip_path_on_drive}"
            shutil.rmtree(LOCAL_TEMP_CHUNK_DIR)
            print(f"    ✅ SUCCESS: Chunk #{current_chunk_num} saved to Drive.")

        # --- D. Clean up temporary files for this model ---
        print(f"\n  D) Cleaning up temporary files for {model_name}...")
        shutil.rmtree(temp_unzip_target, ignore_errors=True)
        shutil.rmtree(temp_extract_target, ignore_errors=True)
        print(f"  --- Finished processing {model_name} ---")

    # --- Final Cleanup ---
    print("\n\n--- All models processed. Final cleanup... ---")
    shutil.rmtree(LOCAL_TEMP_ZIPS_DIR, ignore_errors=True)
    print(f"Your new fake frame chunks have been added to: '{DRIVE_OUTPUT_DIR}'")

# %% [markdown]
# New Real dataset extract, zipped and process

# %%
# === SCRIPT TO EXTRACT FRAMES FROM UCF101 AND ADD-ON TO EXISTING CHUNKS (COMPLETE VERSION) ===

import os
import glob
import time
import shutil
import cv2
import numpy as np
import math
import re
from pathlib import Path
from google.colab import drive

# --- Configuration ---
DRIVE_UCF101_ZIP_PATH = "/content/drive/MyDrive/archive.zip"
DRIVE_OUTPUT_DIR = "/content/drive/MyDrive/zipped"
NUM_FRAMES_TO_EXTRACT = 60
CHUNK_SIZE = 10000
LOCAL_UNZIPPED_VIDEOS_DIR = "/content/UCF101_videos"
LOCAL_EXTRACTED_FRAMES_DIR = "/content/extracted_ucf101_frames"
# --- End of Configuration ---

# --- Helper Function to Extract Evenly Spaced Frames ---
def extract_evenly_spaced_frames(video_path, num_frames, output_folder):
    try:
        cap = cv2.VideoCapture(str(video_path))
        if not cap.isOpened():
            print(f"    - Warning: Could not open {video_path}. Skipping.")
            return []

        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        if total_frames < num_frames:
            # print(f"    - Warning: Video {video_path} has only {total_frames} frames. Skipping.")
            return []

        frame_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)

        saved_frame_paths = []
        video_name = Path(video_path).stem
        # Add a prefix to frame names to avoid any potential name collisions with other datasets
        video_prefix = f"ucf101_{video_name}"

        for i, frame_idx in enumerate(frame_indices):
            cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)
            ret, frame = cap.read()
            if ret:
                output_filename = f"{video_prefix}_frame_{i:03d}.jpg"
                output_path = os.path.join(output_folder, output_filename)
                cv2.imwrite(output_path, frame)
                saved_frame_paths.append(output_path)

        cap.release()
        return saved_frame_paths
    except Exception as e:
        print(f"    - ERROR processing {video_path}: {e}")
        return []

# --- Main Execution Block ---
if __name__ == '__main__':
    print("--- Starting UCF101 Frame Extraction and Zipping (Add-On Mode) ---")
    start_time_total = time.time()
    drive.mount('/content/drive', force_remount=True)

    local_ucf101_zip = f"/content/{Path(DRIVE_UCF101_ZIP_PATH).name}"

    # --- Step 1: Copy and Unzip the Dataset (Resumable) ---
    print("\n--- Step 1: Preparing Local UCF101 Video Dataset ---")
    if not os.path.isdir(LOCAL_UNZIPPED_VIDEOS_DIR):
        if not os.path.exists(local_ucf101_zip):
            print(f"  Copying {DRIVE_UCF101_ZIP_PATH} to local storage...")
            # !cp "{DRIVE_UCF101_ZIP_PATH}" /content/
        else:
            print("  Local zip file found. Skipping copy.")

        print(f"  Unzipping dataset to '{LOCAL_UNZIPPED_VIDEOS_DIR}'...")
        # !unzip -q "{local_ucf101_zip}" -d "{LOCAL_UNZIPPED_VIDEOS_DIR}"
        print("  Unzipping complete.")
    else:
        print("✅ SKIPPING: Local unzipped directory already exists.")

    # --- Step 2: Extract 60 Frames from Each Video (Resumable) ---
    print("\n--- Step 2: Extracting Frames ---")
    os.makedirs(LOCAL_EXTRACTED_FRAMES_DIR, exist_ok=True)

    all_video_files = glob.glob(os.path.join(LOCAL_UNZIPPED_VIDEOS_DIR, '**', '*.avi'), recursive=True)
    print(f"Found {len(all_video_files)} AVI video files to process.")

    # Check if we already have extracted frames to avoid re-extracting everything
    existing_frames_check = glob.glob(os.path.join(LOCAL_EXTRACTED_FRAMES_DIR, "*.jpg"))
    # Heuristic: if more frames exist than videos, assume extraction was done.
    if len(existing_frames_check) > len(all_video_files):
        print("✅ SKIPPING: Found a large number of existing frames. Assuming extraction is complete.")
        all_extracted_frame_paths = sorted(existing_frames_check)
    else:
        all_extracted_frame_paths = []
        for i, video_path in enumerate(all_video_files):
            if (i + 1) % 500 == 0:
                print(f"  Processing video {i+1}/{len(all_video_files)}...")
            frame_paths = extract_evenly_spaced_frames(video_path, NUM_FRAMES_TO_EXTRACT, LOCAL_EXTRACTED_FRAMES_DIR)
            all_extracted_frame_paths.extend(frame_paths)
        all_extracted_frame_paths = sorted(all_extracted_frame_paths)
        print(f"-> Frame extraction complete. Total new frames created: {len(all_extracted_frame_paths)}")

    if not all_extracted_frame_paths:
        print("❌ ERROR: Frame extraction resulted in zero files. Cannot proceed. Please check video paths and formats.")
        import sys
        sys.exit()

    # --- MODIFIED STEP 3: Determine Starting Point and Zip in Add-On Chunks ---
    print("\n--- Step 3: Zipping and Uploading in Add-On Chunks ---")
    os.makedirs(DRIVE_OUTPUT_DIR, exist_ok=True)

    print("  Scanning existing 'real_frames' chunks on Drive to determine starting point...")
    existing_real_chunks = sorted(glob.glob(os.path.join(DRIVE_OUTPUT_DIR, "real_frames_chunk_*.zip")))

    start_chunk_num = 1
    start_file_index = 0

    if existing_real_chunks:
        last_chunk_filename = Path(existing_real_chunks[-1]).name
        print(f"  Last existing chunk found: {last_chunk_filename}")
        match = re.search(r'chunk_(\d+)_(\d+)-(\d+)\.zip', last_chunk_filename)
        if match:
            last_chunk_num = int(match.group(1))
            last_file_index = int(match.group(3))
            start_chunk_num = last_chunk_num + 1
            start_file_index = last_file_index + 1
            print(f"  --> Will start with NEW Chunk #{start_chunk_num}, indexing from file #{start_file_index}.")
        else:
            print("  Warning: Could not parse existing chunk names. Starting from chunk 1.")
    else:
        print("  No existing 'real_frames' chunks found. Starting from chunk 1.")

    total_new_frames = len(all_extracted_frame_paths)
    total_new_chunks = math.ceil(total_new_frames / CHUNK_SIZE)
    print(f"  Will create {total_new_chunks} new chunk(s) for the {total_new_frames} new frames.")

    for i in range(total_new_chunks):
        current_chunk_num = start_chunk_num + i
        start_slice_index = i * CHUNK_SIZE
        end_slice_index = start_slice_index + CHUNK_SIZE
        chunk_of_paths = all_extracted_frame_paths[start_slice_index:end_slice_index]

        current_start_file_index = start_file_index + (i * CHUNK_SIZE)
        current_end_file_index = current_start_file_index + len(chunk_of_paths) - 1

        final_zip_name = f"real_frames_chunk_{current_chunk_num:02d}_{current_start_file_index:06d}-{current_end_file_index:06d}.zip"
        final_zip_path_on_drive = os.path.join(DRIVE_OUTPUT_DIR, final_zip_name)

        print(f"\n--- Processing NEW Chunk #{current_chunk_num}: {final_zip_name} ---")

        if os.path.exists(final_zip_path_on_drive):
            print(f"✅ SKIPPING: This chunk already exists on Google Drive.")
            continue

        LOCAL_TEMP_CHUNK_DIR = f"/content/temp_chunk_{current_chunk_num}"
        shutil.rmtree(LOCAL_TEMP_CHUNK_DIR, ignore_errors=True)
        os.makedirs(LOCAL_TEMP_CHUNK_DIR)

        print(f"  Copying {len(chunk_of_paths)} frames to temp chunk directory...")
        for frame_path in chunk_of_paths:
            shutil.copy(frame_path, LOCAL_TEMP_CHUNK_DIR)

        print("  Zipping chunk locally...")
        local_zip_path = f"/content/{final_zip_name}"
        # !zip -r -q -j "{local_zip_path}" "{LOCAL_TEMP_CHUNK_DIR}/"

        print("  Moving zip file to Google Drive...")
        # !mv "{local_zip_path}" "{final_zip_path_on_drive}"

        shutil.rmtree(LOCAL_TEMP_CHUNK_DIR)
        print(f"✅ SUCCESS: Chunk #{current_chunk_num} saved to Drive.")

    # --- Step 4: Final Cleanup ---
    print("\n--- Step 4: Final Cleanup of Large Local Files ---")
    print(f"  Deleting local unzipped videos: {LOCAL_UNZIPPED_VIDEOS_DIR}")
    shutil.rmtree(LOCAL_UNZIPPED_VIDEOS_DIR, ignore_errors=True)
    print(f"  Deleting local extracted frames: {LOCAL_EXTRACTED_FRAMES_DIR}")
    shutil.rmtree(LOCAL_EXTRACTED_FRAMES_DIR, ignore_errors=True)
    if os.path.exists(local_ucf101_zip):
        print(f"  Deleting local zip file: {local_ucf101_zip}")
        os.remove(local_ucf101_zip)

    end_time_total = time.time()
    print(f"\n\n--- All tasks completed in {end_time_total - start_time_total:.2f} seconds. ---")
# Out:
# --- Starting UCF101 Frame Extraction and Zipping (Add-On Mode) ---
# Mounted at /content/drive
#
# --- Step 1: Preparing Local UCF101 Video Dataset ---
#   Copying /content/drive/MyDrive/archive.zip to local storage...
#   Unzipping dataset to '/content/UCF101_videos'...
#   Unzipping complete.
#
# --- Step 2: Extracting Frames ---
# Found 13451 AVI video files to process.
#   Processing video 500/13451...
#   Processing video 1000/13451...
#   Processing video 1500/13451...
#   Processing video 2000/13451...
#   Processing video 2500/13451...
#   Processing video 3000/13451...
#   Processing video 3500/13451...
#   Processing video 4000/13451...
#   Processing video 4500/13451...
#   Processing video 5000/13451...
#   Processing video 5500/13451...
#   Processing video 6000/13451...
#   Processing video 6500/13451...
#   Processing video 7000/13451...
#   Processing video 7500/13451...
#   Processing video 8000/13451...
#   Processing video 8500/13451...
#   Processing video 9000/13451...
#   Processing video 9500/13451...
#   Processing video 10000/13451...
#   Processing video 10500/13451...
#   Processing video 11000/13451...
#   Processing video 11500/13451...
#   Processing video 12000/13451...
#   Processing video 12500/13451...
#   Processing video 13000/13451...
# -> Frame extraction complete. Total new frames created: 794642
#
# --- Step 3: Zipping and Uploading in Add-On Chunks ---
#   Scanning existing 'real_frames' chunks on Drive to determine starting point...
#   Last existing chunk found: real_frames_chunk_09_080000-089999.zip
#   --> Will start with NEW Chunk #10, indexing from file #90000.
#   Will create 80 new chunk(s) for the 794642 new frames.
#
# --- Processing NEW Chunk #10: real_frames_chunk_10_090000-099999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #10 saved to Drive.
#
# --- Processing NEW Chunk #11: real_frames_chunk_11_100000-109999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #11 saved to Drive.
#
# --- Processing NEW Chunk #12: real_frames_chunk_12_110000-119999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #12 saved to Drive.
#
# --- Processing NEW Chunk #13: real_frames_chunk_13_120000-129999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #13 saved to Drive.
#
# --- Processing NEW Chunk #14: real_frames_chunk_14_130000-139999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #14 saved to Drive.
#
# --- Processing NEW Chunk #15: real_frames_chunk_15_140000-149999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #15 saved to Drive.
#
# --- Processing NEW Chunk #16: real_frames_chunk_16_150000-159999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #16 saved to Drive.
#
# --- Processing NEW Chunk #17: real_frames_chunk_17_160000-169999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #17 saved to Drive.
#
# --- Processing NEW Chunk #18: real_frames_chunk_18_170000-179999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #18 saved to Drive.
#
# --- Processing NEW Chunk #19: real_frames_chunk_19_180000-189999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #19 saved to Drive.
#
# --- Processing NEW Chunk #20: real_frames_chunk_20_190000-199999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #20 saved to Drive.
#
# --- Processing NEW Chunk #21: real_frames_chunk_21_200000-209999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #21 saved to Drive.
#
# --- Processing NEW Chunk #22: real_frames_chunk_22_210000-219999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #22 saved to Drive.
#
# --- Processing NEW Chunk #23: real_frames_chunk_23_220000-229999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #23 saved to Drive.
#
# --- Processing NEW Chunk #24: real_frames_chunk_24_230000-239999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #24 saved to Drive.
#
# --- Processing NEW Chunk #25: real_frames_chunk_25_240000-249999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #25 saved to Drive.
#
# --- Processing NEW Chunk #26: real_frames_chunk_26_250000-259999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #26 saved to Drive.
#
# --- Processing NEW Chunk #27: real_frames_chunk_27_260000-269999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #27 saved to Drive.
#
# --- Processing NEW Chunk #28: real_frames_chunk_28_270000-279999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #28 saved to Drive.
#
# --- Processing NEW Chunk #29: real_frames_chunk_29_280000-289999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #29 saved to Drive.
#
# --- Processing NEW Chunk #30: real_frames_chunk_30_290000-299999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #30 saved to Drive.
#
# --- Processing NEW Chunk #31: real_frames_chunk_31_300000-309999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #31 saved to Drive.
#
# --- Processing NEW Chunk #32: real_frames_chunk_32_310000-319999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #32 saved to Drive.
#
# --- Processing NEW Chunk #33: real_frames_chunk_33_320000-329999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #33 saved to Drive.
#
# --- Processing NEW Chunk #34: real_frames_chunk_34_330000-339999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #34 saved to Drive.
#
# --- Processing NEW Chunk #35: real_frames_chunk_35_340000-349999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #35 saved to Drive.
#
# --- Processing NEW Chunk #36: real_frames_chunk_36_350000-359999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #36 saved to Drive.
#
# --- Processing NEW Chunk #37: real_frames_chunk_37_360000-369999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #37 saved to Drive.
#
# --- Processing NEW Chunk #38: real_frames_chunk_38_370000-379999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #38 saved to Drive.
#
# --- Processing NEW Chunk #39: real_frames_chunk_39_380000-389999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #39 saved to Drive.
#
# --- Processing NEW Chunk #40: real_frames_chunk_40_390000-399999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #40 saved to Drive.
#
# --- Processing NEW Chunk #41: real_frames_chunk_41_400000-409999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #41 saved to Drive.
#
# --- Processing NEW Chunk #42: real_frames_chunk_42_410000-419999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #42 saved to Drive.
#
# --- Processing NEW Chunk #43: real_frames_chunk_43_420000-429999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #43 saved to Drive.
#
# --- Processing NEW Chunk #44: real_frames_chunk_44_430000-439999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #44 saved to Drive.
#
# --- Processing NEW Chunk #45: real_frames_chunk_45_440000-449999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #45 saved to Drive.
#
# --- Processing NEW Chunk #46: real_frames_chunk_46_450000-459999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #46 saved to Drive.
#
# --- Processing NEW Chunk #47: real_frames_chunk_47_460000-469999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #47 saved to Drive.
#
# --- Processing NEW Chunk #48: real_frames_chunk_48_470000-479999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #48 saved to Drive.
#
# --- Processing NEW Chunk #49: real_frames_chunk_49_480000-489999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #49 saved to Drive.
#
# --- Processing NEW Chunk #50: real_frames_chunk_50_490000-499999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #50 saved to Drive.
#
# --- Processing NEW Chunk #51: real_frames_chunk_51_500000-509999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #51 saved to Drive.
#
# --- Processing NEW Chunk #52: real_frames_chunk_52_510000-519999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #52 saved to Drive.
#
# --- Processing NEW Chunk #53: real_frames_chunk_53_520000-529999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #53 saved to Drive.
#
# --- Processing NEW Chunk #54: real_frames_chunk_54_530000-539999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #54 saved to Drive.
#
# --- Processing NEW Chunk #55: real_frames_chunk_55_540000-549999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #55 saved to Drive.
#
# --- Processing NEW Chunk #56: real_frames_chunk_56_550000-559999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #56 saved to Drive.
#
# --- Processing NEW Chunk #57: real_frames_chunk_57_560000-569999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #57 saved to Drive.
#
# --- Processing NEW Chunk #58: real_frames_chunk_58_570000-579999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #58 saved to Drive.
#
# --- Processing NEW Chunk #59: real_frames_chunk_59_580000-589999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #59 saved to Drive.
#
# --- Processing NEW Chunk #60: real_frames_chunk_60_590000-599999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #60 saved to Drive.
#
# --- Processing NEW Chunk #61: real_frames_chunk_61_600000-609999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #61 saved to Drive.
#
# --- Processing NEW Chunk #62: real_frames_chunk_62_610000-619999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #62 saved to Drive.
#
# --- Processing NEW Chunk #63: real_frames_chunk_63_620000-629999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #63 saved to Drive.
#
# --- Processing NEW Chunk #64: real_frames_chunk_64_630000-639999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #64 saved to Drive.
#
# --- Processing NEW Chunk #65: real_frames_chunk_65_640000-649999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #65 saved to Drive.
#
# --- Processing NEW Chunk #66: real_frames_chunk_66_650000-659999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #66 saved to Drive.
#
# --- Processing NEW Chunk #67: real_frames_chunk_67_660000-669999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #67 saved to Drive.
#
# --- Processing NEW Chunk #68: real_frames_chunk_68_670000-679999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #68 saved to Drive.
#
# --- Processing NEW Chunk #69: real_frames_chunk_69_680000-689999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #69 saved to Drive.
#
# --- Processing NEW Chunk #70: real_frames_chunk_70_690000-699999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #70 saved to Drive.
#
# --- Processing NEW Chunk #71: real_frames_chunk_71_700000-709999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #71 saved to Drive.
#
# --- Processing NEW Chunk #72: real_frames_chunk_72_710000-719999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #72 saved to Drive.
#
# --- Processing NEW Chunk #73: real_frames_chunk_73_720000-729999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #73 saved to Drive.
#
# --- Processing NEW Chunk #74: real_frames_chunk_74_730000-739999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #74 saved to Drive.
#
# --- Processing NEW Chunk #75: real_frames_chunk_75_740000-749999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #75 saved to Drive.
#
# --- Processing NEW Chunk #76: real_frames_chunk_76_750000-759999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #76 saved to Drive.
#
# --- Processing NEW Chunk #77: real_frames_chunk_77_760000-769999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #77 saved to Drive.
#
# --- Processing NEW Chunk #78: real_frames_chunk_78_770000-779999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #78 saved to Drive.
#
# --- Processing NEW Chunk #79: real_frames_chunk_79_780000-789999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #79 saved to Drive.
#
# --- Processing NEW Chunk #80: real_frames_chunk_80_790000-799999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #80 saved to Drive.
#
# --- Processing NEW Chunk #81: real_frames_chunk_81_800000-809999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #81 saved to Drive.
#
# --- Processing NEW Chunk #82: real_frames_chunk_82_810000-819999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #82 saved to Drive.
#
# --- Processing NEW Chunk #83: real_frames_chunk_83_820000-829999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #83 saved to Drive.
#
# --- Processing NEW Chunk #84: real_frames_chunk_84_830000-839999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #84 saved to Drive.
#
# --- Processing NEW Chunk #85: real_frames_chunk_85_840000-849999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #85 saved to Drive.
#
# --- Processing NEW Chunk #86: real_frames_chunk_86_850000-859999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #86 saved to Drive.
#
# --- Processing NEW Chunk #87: real_frames_chunk_87_860000-869999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #87 saved to Drive.
#
# --- Processing NEW Chunk #88: real_frames_chunk_88_870000-879999.zip ---
#   Copying 10000 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #88 saved to Drive.
#
# --- Processing NEW Chunk #89: real_frames_chunk_89_880000-884641.zip ---
#   Copying 4642 frames to temp chunk directory...
#   Zipping chunk locally...
#   Moving zip file to Google Drive...
# ✅ SUCCESS: Chunk #89 saved to Drive.
#
# --- Step 4: Final Cleanup of Large Local Files ---
#   Deleting local unzipped videos: /content/UCF101_videos
#   Deleting local extracted frames: /content/extracted_ucf101_frames
#   Deleting local zip file: /content/archive.zip
#
#
# --- All tasks completed in 14478.15 seconds. ---

# %%
# !fusermount -u /content/drive
# !rm -rf /content/drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# fusermount: failed to unmount /content/drive: Invalid argument
# Mounted at /content/drive

# %%
import time
import os
import shutil # Import shutil for rmtree

# In a Colab cell, before your main script
from google.colab import drive

# Attempt to unmount and flush. If it fails, it means it wasn't mounted
# or there was an issue. We'll handle the directory cleanup next.
try:
    drive.flush_and_unmount()
    print("Attempted Drive flush and unmount.")
except ValueError:
    print("Drive was not mounted or could not be unmounted. Proceeding to directory cleanup.")
except Exception as e:
    print(f"An error occurred during flush/unmount: {e}. Proceeding to directory cleanup.")


time.sleep(2) # Short pause after unmounting attempt

# Explicitly remove the mountpoint directory if it exists and is not empty
mountpoint = '/content/drive'
if os.path.exists(mountpoint):
    print(f"Cleaning up mountpoint directory: {mountpoint}")
    try:
        # Use shutil.rmtree to remove directory and its contents recursively
        shutil.rmtree(mountpoint)
        print(f"Successfully removed {mountpoint}")
    except OSError as e:
        print(f"Error removing mountpoint {mountpoint}: {e}")
        # If removal fails, we might still have issues. Exit gracefully or raise error.
        # For now, just print error and proceed, mount might still fail.
        pass # Continue attempting to mount even if cleanup failed

# Recreate the mountpoint directory as an empty directory for mounting
os.makedirs(mountpoint, exist_ok=True)
print(f"Ensured mountpoint directory exists and is empty: {mountpoint}")

time.sleep(2) # Short pause before mounting

# Now attempt to mount
try:
    drive.mount(mountpoint, force_remount=True)
    print("Drive remounted successfully.")
except Exception as e:
    print(f"FATAL: Could not mount Google Drive after cleanup. Error: {e}. Please check permissions and try again.")
# Out:
# Attempted Drive flush and unmount.
# Ensured mountpoint directory exists and is empty: /content/drive
# Mounted at /content/drive
# Drive remounted successfully.

# %% [markdown]
# Computing Optical Flow

# %%
import cv2
import numpy as np
import os
from pathlib import Path
import torch
import glob
from collections import defaultdict
import time
import re
import gc
import random
from google.colab import drive

# --- Configuration ---
# Target sequence length for this preprocessing step
SEQUENCE_LENGTH = 30
# Step size for creating sequences. Set to SEQUENCE_LENGTH for non-overlapping.
STEP_SIZE = 30

# --- PATHS ---
# INPUT: The directories with your extracted 60 frames per video
INPUT_REAL_FRAMES_DIR = '/content/drive/MyDrive/final_balanced_data/real_frames'
INPUT_FAKE_FRAMES_DIR = '/content/drive/MyDrive/final_balanced_data/fake_frames'

# OUTPUT: A directory for the new flow features
DRIVE_PRECOMPUTED_FLOW_DIR = f'/content/drive/MyDrive/final_balanced_data/precomputed_flow{SEQUENCE_LENGTH}_SS{STEP_SIZE}'
os.makedirs(DRIVE_PRECOMPUTED_FLOW_DIR, exist_ok=True)
print(f"Precomputed optical flow sequences will be saved to: {DRIVE_PRECOMPUTED_FLOW_DIR}")

# --- Mount Google Drive ---

try:
    drive.mount('/content/drive', force_remount=True)
    print("Google Drive mounted.")
except Exception as e:
    print(f"FATAL: Could not mount Google Drive. Error: {e}. Exiting.")
    # In a notebook, this will just stop the cell.
    exit()



# --- Helper Functions ---
def group_frames_by_video(frame_paths, class_label_for_debug=""):
    """Groups frame paths based on the video stem in their filename."""
    video_groups = defaultdict(list)
    for path_str in frame_paths:
        path_obj = Path(str(path_str))
        stem = path_obj.stem
        # Use the corrected regex to handle 'frame' or 'f' prefixes
        match = re.match(r'^(.*?)_(?:frame|f)(\d+)', stem)
        if match:
            video_stem = match.group(1)
        else:
            # Fallback if the naming convention is ever different
            print(f"WARN: Could not parse video stem from filename '{stem}'. Using stem as fallback.")
            video_stem = stem
        video_groups[video_stem].append(str(path_str))

    # Sort frames within each group by their frame number
    for stem_key in list(video_groups.keys()):
        try:
            video_groups[stem_key] = sorted(
                video_groups[stem_key],
                key=lambda x: int(re.match(r'^(.*?)_(?:frame|f)(\d+)', Path(x).stem).group(2))
            )
        except: # Fallback to alphanumeric sort if number parsing fails
            video_groups[stem_key] = sorted(video_groups[stem_key])

    print(f"  Grouped {len(frame_paths)} frames into {len(video_groups)} video groups for '{class_label_for_debug}'.")
    return video_groups

def compute_optical_flow_for_one_sequence(bgr_frames_list, target_sequence_length):
    """Computes flow for a single sequence of BGR frames."""
    flow_features_for_seq = [np.array([0.0, 0.0], dtype=np.float32)] # First flow is 0
    num_pairs_to_compute = len(bgr_frames_list) - 1
    for i in range(num_pairs_to_compute):
        prev_bgr_frame, curr_bgr_frame = bgr_frames_list[i], bgr_frames_list[i+1]
        if prev_bgr_frame is None or curr_bgr_frame is None:
            flow_features_for_seq.append(np.array([0.0, 0.0], dtype=np.float32)); continue
        try:
            prev_gray = cv2.cvtColor(prev_bgr_frame, cv2.COLOR_BGR2GRAY)
            curr_gray = cv2.cvtColor(curr_bgr_frame, cv2.COLOR_BGR2GRAY)
            if prev_gray.shape != curr_gray.shape:
                flow_features_for_seq.append(np.array([0.0, 0.0], dtype=np.float32)); continue
            flow_cv = cv2.calcOpticalFlowFarneback(prev_gray, curr_gray, None, 0.5, 3, 15, 3, 5, 1.2, 0)
            if flow_cv is not None:
                magnitude = np.sqrt(flow_cv[..., 0]**2 + flow_cv[..., 1]**2)
                flow_features_for_seq.append(np.array([np.mean(magnitude), np.var(magnitude)], dtype=np.float32) if magnitude.size > 0 else np.array([0.0,0.0], dtype=np.float32))
            else:
                flow_features_for_seq.append(np.array([0.0, 0.0], dtype=np.float32))
        except Exception:
            flow_features_for_seq.append(np.array([0.0, 0.0], dtype=np.float32))
    return torch.tensor(np.array(flow_features_for_seq), dtype=torch.float32)

# --- Main Preprocessing Function ---
# --- Main Preprocessing Function (Modified for better logging) ---
def preprocess_and_save_flow(all_sequences_to_process, save_dir, sequence_len):
    """
    Takes a list of sequence info tuples and processes them,
    logging when it moves to a new source video.
    """
    total_sequences_generated_this_run = 0
    print(f"Attempting to generate flow for {len(all_sequences_to_process)} sequences...")

    last_video_stem_processed = None # Keep track of the last video

    for seq_idx, (frame_paths, sequence_identifier) in enumerate(all_sequences_to_process):
        # Extract the video stem from the sequence_identifier for logging
        # Assumes format like: "real_VIDEOSTEM_seqX"
        current_video_stem = "_".join(sequence_identifier.split('_')[1:-1])

        # If the video stem has changed, print a header for the new video
        if current_video_stem != last_video_stem_processed:
            print(f"\n  Now processing sequences from video: '{current_video_stem}'")
            last_video_stem_processed = current_video_stem

        # More targeted log for the sequence itself
        if (seq_idx + 1) % 10 == 0 or seq_idx < 5: # Log first 5 and then every 10th
            print(f"    - Processing sequence {seq_idx + 1}/{len(all_sequences_to_process)} ('{sequence_identifier}')...")

        save_path = os.path.join(save_dir, f"{sequence_identifier}_flow.pt")

        if os.path.exists(save_path):
            continue # Skip if already exists (resume logic)

        # Load BGR frames for THIS sequence
        seq_bgr_frames = []
        for frame_path in frame_paths:
            frame = cv2.imread(frame_path)
            if frame is not None:
                seq_bgr_frames.append(frame)

        # Ensure we have the correct number of frames before computing flow
        if len(seq_bgr_frames) == sequence_len:
            flow_tensor = compute_optical_flow_for_one_sequence(seq_bgr_frames, sequence_len)
            if flow_tensor is not None and flow_tensor.shape == (sequence_len, 2):
                torch.save(flow_tensor, save_path)
                total_sequences_generated_this_run += 1

        del seq_bgr_frames
        if (seq_idx + 1) % 200 == 0:
            gc.collect()

    print(f"--- Finished precomputing. Generated {total_sequences_generated_this_run} new flow sequences. ---")

# --- Main Execution Block ---
if __name__ == '__main__':
    print("********************************************************************************")
    print("*** Optical Flow Preprocessing for Balanced, Fixed-Frame-Count Datasets      ***")
    print(f"*** Target Sequence Length for Flow: {SEQUENCE_LENGTH}, Step Size: {STEP_SIZE}            ***")
    print("********************************************************************************")

    print(f"\n--- Loading Frame Paths from balanced frame directories ---")
    img_patterns = ["*.[jJ][pP][gG]", "*.[jJ][pP][eE][gG]", "*.[pP][nN][gG]"]
    all_real_frame_paths = sorted([p for pattern in img_patterns for p in glob.glob(os.path.join(INPUT_REAL_FRAMES_DIR, '**', pattern), recursive=True)])
    all_fake_frame_paths = sorted([p for pattern in img_patterns for p in glob.glob(os.path.join(INPUT_FAKE_FRAMES_DIR, '**', pattern), recursive=True)])
    print(f"Found {len(all_real_frame_paths)} total real frames and {len(all_fake_frame_paths)} total fake frames.")

    print("\n--- Grouping frames and creating sequences ---")
    real_video_groups = group_frames_by_video(all_real_frame_paths, "real")
    fake_video_groups = group_frames_by_video(all_fake_frame_paths, "fake")

    all_sequences_to_process_info = []
    # For REAL videos
    for video_stem, frames_list in real_video_groups.items():
        if len(frames_list) < SEQUENCE_LENGTH: continue
        for i in range(0, len(frames_list) - SEQUENCE_LENGTH + 1, STEP_SIZE):
            seq_paths = frames_list[i : i + SEQUENCE_LENGTH]
            if len(seq_paths) == SEQUENCE_LENGTH:
                safe_stem = re.sub(r'[\\/*?:"<>|]',"_", str(video_stem))
                seq_id = f"real_{safe_stem}_seq{i//STEP_SIZE}"
                all_sequences_to_process_info.append((seq_paths, seq_id, "real"))
    # For FAKE videos
    for video_stem, frames_list in fake_video_groups.items():
        if len(frames_list) < SEQUENCE_LENGTH: continue
        for i in range(0, len(frames_list) - SEQUENCE_LENGTH + 1, STEP_SIZE):
            seq_paths = frames_list[i : i + SEQUENCE_LENGTH]
            if len(seq_paths) == SEQUENCE_LENGTH:
                safe_stem = re.sub(r'[\\/*?:"<>|]',"_", str(video_stem))
                seq_id = f"fake_{safe_stem}_seq{i//STEP_SIZE}"
                all_sequences_to_process_info.append((seq_paths, seq_id, "fake"))

    print("\n--- Balancing at the sequence level ---")
    real_sequences = [item for item in all_sequences_to_process_info if item[2] == "real"]
    fake_sequences = [item for item in all_sequences_to_process_info if item[2] == "fake"]
    print(f"Generated {len(real_sequences)} real sequences and {len(fake_sequences)} fake sequences.")

    final_real_sequences_to_process = []
    final_fake_sequences_to_process = []

    if not real_sequences or not fake_sequences:
        print("One class has zero sequences. Cannot balance. Processing all available.")
        final_real_sequences_to_process = [(item[0], item[1]) for item in real_sequences]
        final_fake_sequences_to_process = [(item[0], item[1]) for item in fake_sequences]
    else:
        min_seq_count = min(len(real_sequences), len(fake_sequences))
        print(f"Balancing to {min_seq_count} sequences per class.")

        random.seed(42) # For reproducible sampling
        real_sequences_sampled = random.sample(real_sequences, min_seq_count)
        fake_sequences_sampled = random.sample(fake_sequences, min_seq_count)

        final_real_sequences_to_process = [(item[0], item[1]) for item in real_sequences_sampled]
        final_fake_sequences_to_process = [(item[0], item[1]) for item in fake_sequences_sampled]

    # --- MODIFICATION: Sort the lists before processing ---
    # Sorting by the sequence identifier (the second element of the tuple)
    # This will group '..._seq0', '..._seq1', etc. for the same video together.
    final_real_sequences_to_process.sort(key=lambda x: x[1])
    final_fake_sequences_to_process.sort(key=lambda x: x[1])

    print(f"Total REAL sequences to process (sorted): {len(final_real_sequences_to_process)}")
    print(f"Total FAKE sequences to process (sorted): {len(final_fake_sequences_to_process)}")

    # --- Run the main processing function SEQUENTIALLY for each class ---
    if final_real_sequences_to_process:
        print("\n--- Starting Optical Flow Computation for REAL sequences ---")
        preprocess_and_save_flow(
            final_real_sequences_to_process,
            DRIVE_PRECOMPUTED_FLOW_DIR,
            SEQUENCE_LENGTH
        )
    else:
        print("\nNo REAL sequences to process.")

    gc.collect() # Garbage collect between the two large processing tasks

    if final_fake_sequences_to_process:
        print("\n--- Starting Optical Flow Computation for FAKE sequences ---")
        preprocess_and_save_flow(
            final_fake_sequences_to_process,
            DRIVE_PRECOMPUTED_FLOW_DIR,
            SEQUENCE_LENGTH
        )
    else:
        print("\nNo FAKE sequences to process.")

    print("\n--- Optical Flow Preprocessing is DONE ---")
# Out:
# Streaming output truncated to the last 5000 lines.
#
#   Now processing sequences from video: '330'
#
#   Now processing sequences from video: '331'
#     - Processing sequence 1390/2726 ('real_331_seq1')...
#
#   Now processing sequences from video: '332'
#
#   Now processing sequences from video: '333'
#
#   Now processing sequences from video: '334'
#
#   Now processing sequences from video: '335'
#
#   Now processing sequences from video: '336'
#     - Processing sequence 1400/2726 ('real_336_seq1')...
#
#   Now processing sequences from video: '337'
#
#   Now processing sequences from video: '338'
#
#   Now processing sequences from video: '339'
#
#   Now processing sequences from video: '340'
#
#   Now processing sequences from video: '341'
#     - Processing sequence 1410/2726 ('real_341_seq1')...
#
#   Now processing sequences from video: '342'
#
#   Now processing sequences from video: '343'
#
#   Now processing sequences from video: '344'
#
#   Now processing sequences from video: '345'
#
#   Now processing sequences from video: '346'
#     - Processing sequence 1420/2726 ('real_346_seq1')...
#
#   Now processing sequences from video: '347'
#
#   Now processing sequences from video: '348'
#
#   Now processing sequences from video: '349'
#
#   Now processing sequences from video: '350'
#
#   Now processing sequences from video: '351'
#     - Processing sequence 1430/2726 ('real_351_seq1')...
#
#   Now processing sequences from video: '352'
#
#   Now processing sequences from video: '353'
#
#   Now processing sequences from video: '354'
#
#   Now processing sequences from video: '355'
#
#   Now processing sequences from video: '356'
#     - Processing sequence 1440/2726 ('real_356_seq1')...
#
#   Now processing sequences from video: '357'
#
#   Now processing sequences from video: '358'
#
#   Now processing sequences from video: '359'
#
#   Now processing sequences from video: '360'
#
#   Now processing sequences from video: '361'
#     - Processing sequence 1450/2726 ('real_361_seq1')...
#
#   Now processing sequences from video: '362'
#
#   Now processing sequences from video: '363'
#
#   Now processing sequences from video: '364'
#
#   Now processing sequences from video: '365'
#
#   Now processing sequences from video: '366'
#     - Processing sequence 1460/2726 ('real_366_seq1')...
#
#   Now processing sequences from video: '367'
#
#   Now processing sequences from video: '368'
#
#   Now processing sequences from video: '369'
#
#   Now processing sequences from video: '370'
#
#   Now processing sequences from video: '371'
#     - Processing sequence 1470/2726 ('real_371_seq1')...
#
#   Now processing sequences from video: '372'
#
#   Now processing sequences from video: '373'
#
#   Now processing sequences from video: '374'
#
#   Now processing sequences from video: '375'
#
#   Now processing sequences from video: '376'
#     - Processing sequence 1480/2726 ('real_376_seq1')...
#
#   Now processing sequences from video: '377'
#
#   Now processing sequences from video: '378'
#
#   Now processing sequences from video: '379'
#
#   Now processing sequences from video: '380'
#
#   Now processing sequences from video: '381'
#     - Processing sequence 1490/2726 ('real_381_seq1')...
#
#   Now processing sequences from video: '382'
#
#   Now processing sequences from video: '383'
#
#   Now processing sequences from video: '384'
#
#   Now processing sequences from video: '385'
#
#   Now processing sequences from video: '386'
#     - Processing sequence 1500/2726 ('real_386_seq1')...
#
#   Now processing sequences from video: '387'
#
#   Now processing sequences from video: '388'
#
#   Now processing sequences from video: '389'
#
#   Now processing sequences from video: '390'
#
#   Now processing sequences from video: '391'
#     - Processing sequence 1510/2726 ('real_391_seq1')...
#
#   Now processing sequences from video: '392'
#
#   Now processing sequences from video: '393'
#
#   Now processing sequences from video: '394'
#
#   Now processing sequences from video: '395'
#
#   Now processing sequences from video: '396'
#     - Processing sequence 1520/2726 ('real_396_seq1')...
#
#   Now processing sequences from video: '397'
#
#   Now processing sequences from video: '398'
#
#   Now processing sequences from video: '399'
#
#   Now processing sequences from video: '400'
#
#   Now processing sequences from video: '401'
#     - Processing sequence 1530/2726 ('real_401_seq1')...
#
#   Now processing sequences from video: '402'
#
#   Now processing sequences from video: '403'
#
#   Now processing sequences from video: '404'
#
#   Now processing sequences from video: '405'
#
#   Now processing sequences from video: '406'
#     - Processing sequence 1540/2726 ('real_406_seq1')...
#
#   Now processing sequences from video: '407'
#
#   Now processing sequences from video: '408'
#
#   Now processing sequences from video: '409'
#
#   Now processing sequences from video: '410'
#
#   Now processing sequences from video: '411'
#     - Processing sequence 1550/2726 ('real_411_seq1')...
#
#   Now processing sequences from video: '412'
#
#   Now processing sequences from video: '413'
#
#   Now processing sequences from video: '414'
#
#   Now processing sequences from video: '415'
#
#   Now processing sequences from video: '416'
#     - Processing sequence 1560/2726 ('real_416_seq1')...
#
#   Now processing sequences from video: '417'
#
#   Now processing sequences from video: '418'
#
#   Now processing sequences from video: '419'
#
#   Now processing sequences from video: '420'
#
#   Now processing sequences from video: '421'
#     - Processing sequence 1570/2726 ('real_421_seq1')...
#
#   Now processing sequences from video: '422'
#
#   Now processing sequences from video: '423'
#
#   Now processing sequences from video: '424'
#
#   Now processing sequences from video: '425'
#
#   Now processing sequences from video: '426'
#     - Processing sequence 1580/2726 ('real_426_seq1')...
#
#   Now processing sequences from video: '427'
#
#   Now processing sequences from video: '428'
#
#   Now processing sequences from video: '429'
#
#   Now processing sequences from video: '430'
#
#   Now processing sequences from video: '431'
#     - Processing sequence 1590/2726 ('real_431_seq1')...
#
#   Now processing sequences from video: '432'
#
#   Now processing sequences from video: '433'
#
#   Now processing sequences from video: '434'
#
#   Now processing sequences from video: '435'
#
#   Now processing sequences from video: '436'
#     - Processing sequence 1600/2726 ('real_436_seq1')...
#
#   Now processing sequences from video: '437'
#
#   Now processing sequences from video: '438'
#
#   Now processing sequences from video: '439'
#
#   Now processing sequences from video: '440'
#
#   Now processing sequences from video: '441'
#     - Processing sequence 1610/2726 ('real_441_seq1')...
#
#   Now processing sequences from video: '442'
#
#   Now processing sequences from video: '443'
#
#   Now processing sequences from video: '444'
#
#   Now processing sequences from video: '445'
#
#   Now processing sequences from video: '446'
#     - Processing sequence 1620/2726 ('real_446_seq1')...
#
#   Now processing sequences from video: '447'
#
#   Now processing sequences from video: '448'
#
#   Now processing sequences from video: '449'
#
#   Now processing sequences from video: '450'
#
#   Now processing sequences from video: '451'
#     - Processing sequence 1630/2726 ('real_451_seq1')...
#
#   Now processing sequences from video: '452'
#
#   Now processing sequences from video: '453'
#
#   Now processing sequences from video: '454'
#
#   Now processing sequences from video: '455'
#
#   Now processing sequences from video: '456'
#     - Processing sequence 1640/2726 ('real_456_seq1')...
#
#   Now processing sequences from video: '457'
#
#   Now processing sequences from video: '458'
#
#   Now processing sequences from video: '459'
#
#   Now processing sequences from video: '460'
#
#   Now processing sequences from video: '461'
#     - Processing sequence 1650/2726 ('real_461_seq1')...
#
#   Now processing sequences from video: '462'
#
#   Now processing sequences from video: '463'
#
#   Now processing sequences from video: '464'
#
#   Now processing sequences from video: '465'
#
#   Now processing sequences from video: '466'
#     - Processing sequence 1660/2726 ('real_466_seq1')...
#
#   Now processing sequences from video: '467'
#
#   Now processing sequences from video: '468'
#
#   Now processing sequences from video: '469'
#
#   Now processing sequences from video: '470'
#
#   Now processing sequences from video: '471'
#     - Processing sequence 1670/2726 ('real_471_seq1')...
#
#   Now processing sequences from video: '472'
#
#   Now processing sequences from video: '473'
#
#   Now processing sequences from video: '474'
#
#   Now processing sequences from video: '475'
#
#   Now processing sequences from video: '476'
#     - Processing sequence 1680/2726 ('real_476_seq1')...
#
#   Now processing sequences from video: '477'
#
#   Now processing sequences from video: '478'
#
#   Now processing sequences from video: '479'
#
#   Now processing sequences from video: '480'
#
#   Now processing sequences from video: '481'
#     - Processing sequence 1690/2726 ('real_481_seq1')...
#
#   Now processing sequences from video: '482'
#
#   Now processing sequences from video: '483'
#
#   Now processing sequences from video: '484'
#
#   Now processing sequences from video: '485'
#
#   Now processing sequences from video: '486'
#     - Processing sequence 1700/2726 ('real_486_seq1')...
#
#   Now processing sequences from video: '487'
#
#   Now processing sequences from video: '488'
#
#   Now processing sequences from video: '489'
#
#   Now processing sequences from video: '490'
#
#   Now processing sequences from video: '491'
#     - Processing sequence 1710/2726 ('real_491_seq1')...
#
#   Now processing sequences from video: '492'
#
#   Now processing sequences from video: '493'
#
#   Now processing sequences from video: '494'
#
#   Now processing sequences from video: '495'
#
#   Now processing sequences from video: '496'
#     - Processing sequence 1720/2726 ('real_496_seq1')...
#
#   Now processing sequences from video: '497'
#
#   Now processing sequences from video: '498'
#
#   Now processing sequences from video: '499'
#
#   Now processing sequences from video: '500'
#
#   Now processing sequences from video: '501'
#     - Processing sequence 1730/2726 ('real_501_seq1')...
#
#   Now processing sequences from video: '502'
#
#   Now processing sequences from video: '503'
#
#   Now processing sequences from video: '504'
#
#   Now processing sequences from video: '505'
#
#   Now processing sequences from video: '506'
#     - Processing sequence 1740/2726 ('real_506_seq1')...
#
#   Now processing sequences from video: '507'
#
#   Now processing sequences from video: '508'
#
#   Now processing sequences from video: '509'
#
#   Now processing sequences from video: '510'
#
#   Now processing sequences from video: '511'
#     - Processing sequence 1750/2726 ('real_511_seq1')...
#
#   Now processing sequences from video: '512'
#
#   Now processing sequences from video: '513'
#
#   Now processing sequences from video: '514'
#
#   Now processing sequences from video: '515'
#
#   Now processing sequences from video: '516'
#     - Processing sequence 1760/2726 ('real_516_seq1')...
#
#   Now processing sequences from video: '517'
#
#   Now processing sequences from video: '518'
#
#   Now processing sequences from video: '519'
#
#   Now processing sequences from video: '520'
#
#   Now processing sequences from video: '521'
#     - Processing sequence 1770/2726 ('real_521_seq1')...
#
#   Now processing sequences from video: '522'
#
#   Now processing sequences from video: '523'
#
#   Now processing sequences from video: '524'
#
#   Now processing sequences from video: '525'
#
#   Now processing sequences from video: '526'
#     - Processing sequence 1780/2726 ('real_526_seq1')...
#
#   Now processing sequences from video: '527'
#
#   Now processing sequences from video: '528'
#
#   Now processing sequences from video: '529'
#
#   Now processing sequences from video: '530'
#
#   Now processing sequences from video: '531'
#     - Processing sequence 1790/2726 ('real_531_seq1')...
#
#   Now processing sequences from video: '532'
#
#   Now processing sequences from video: '533'
#
#   Now processing sequences from video: '534'
#
#   Now processing sequences from video: '535'
#
#   Now processing sequences from video: '536'
#     - Processing sequence 1800/2726 ('real_536_seq1')...
#
#   Now processing sequences from video: '537'
#
#   Now processing sequences from video: '538'
#
#   Now processing sequences from video: '539'
#
#   Now processing sequences from video: '540'
#
#   Now processing sequences from video: '541'
#     - Processing sequence 1810/2726 ('real_541_seq1')...
#
#   Now processing sequences from video: '542'
#
#   Now processing sequences from video: '543'
#
#   Now processing sequences from video: '544'
#
#   Now processing sequences from video: '545'
#
#   Now processing sequences from video: '546'
#     - Processing sequence 1820/2726 ('real_546_seq1')...
#
#   Now processing sequences from video: '547'
#
#   Now processing sequences from video: '548'
#
#   Now processing sequences from video: '549'
#
#   Now processing sequences from video: '550'
#
#   Now processing sequences from video: '551'
#     - Processing sequence 1830/2726 ('real_551_seq1')...
#
#   Now processing sequences from video: '552'
#
#   Now processing sequences from video: '553'
#
#   Now processing sequences from video: '554'
#
#   Now processing sequences from video: '555'
#
#   Now processing sequences from video: '556'
#     - Processing sequence 1840/2726 ('real_556_seq1')...
#
#   Now processing sequences from video: '557'
#
#   Now processing sequences from video: '558'
#
#   Now processing sequences from video: '559'
#
#   Now processing sequences from video: '560'
#
#   Now processing sequences from video: '561'
#     - Processing sequence 1850/2726 ('real_561_seq1')...
#
#   Now processing sequences from video: '562'
#
#   Now processing sequences from video: '563'
#
#   Now processing sequences from video: '564'
#
#   Now processing sequences from video: '565'
#
#   Now processing sequences from video: '566'
#     - Processing sequence 1860/2726 ('real_566_seq1')...
#
#   Now processing sequences from video: '567'
#
#   Now processing sequences from video: '568'
#
#   Now processing sequences from video: '569'
#
#   Now processing sequences from video: '570'
#
#   Now processing sequences from video: '571'
#     - Processing sequence 1870/2726 ('real_571_seq1')...
#
#   Now processing sequences from video: '572'
#
#   Now processing sequences from video: '573'
#
#   Now processing sequences from video: '574'
#
#   Now processing sequences from video: '575'
#
#   Now processing sequences from video: '576'
#     - Processing sequence 1880/2726 ('real_576_seq1')...
#
#   Now processing sequences from video: '577'
#
#   Now processing sequences from video: '578'
#
#   Now processing sequences from video: '579'
#
#   Now processing sequences from video: '580'
#
#   Now processing sequences from video: '581'
#     - Processing sequence 1890/2726 ('real_581_seq1')...
#
#   Now processing sequences from video: '582'
#
#   Now processing sequences from video: '583'
#
#   Now processing sequences from video: '584'
#
#   Now processing sequences from video: '585'
#
#   Now processing sequences from video: '586'
#     - Processing sequence 1900/2726 ('real_586_seq1')...
#
#   Now processing sequences from video: '587'
#
#   Now processing sequences from video: '588'
#
#   Now processing sequences from video: '589'
#
#   Now processing sequences from video: '590'
#
#   Now processing sequences from video: '591'
#     - Processing sequence 1910/2726 ('real_591_seq1')...
#
#   Now processing sequences from video: '592'
#
#   Now processing sequences from video: '593'
#
#   Now processing sequences from video: '594'
#
#   Now processing sequences from video: '595'
#
#   Now processing sequences from video: '596'
#     - Processing sequence 1920/2726 ('real_596_seq1')...
#
#   Now processing sequences from video: '597'
#
#   Now processing sequences from video: '598'
#
#   Now processing sequences from video: '599'
#
#   Now processing sequences from video: '600'
#
#   Now processing sequences from video: '601'
#     - Processing sequence 1930/2726 ('real_601_seq1')...
#
#   Now processing sequences from video: '602'
#
#   Now processing sequences from video: '603'
#
#   Now processing sequences from video: '604'
#
#   Now processing sequences from video: '605'
#
#   Now processing sequences from video: '606'
#     - Processing sequence 1940/2726 ('real_606_seq1')...
#
#   Now processing sequences from video: '607'
#
#   Now processing sequences from video: '608'
#
#   Now processing sequences from video: '609'
#
#   Now processing sequences from video: '610'
#
#   Now processing sequences from video: '611'
#     - Processing sequence 1950/2726 ('real_611_seq1')...
#
#   Now processing sequences from video: '612'
#
#   Now processing sequences from video: '613'
#
#   Now processing sequences from video: '614'
#
#   Now processing sequences from video: '615'
#
#   Now processing sequences from video: '616'
#     - Processing sequence 1960/2726 ('real_616_seq1')...
#
#   Now processing sequences from video: '617'
#
#   Now processing sequences from video: '618'
#
#   Now processing sequences from video: '619'
#
#   Now processing sequences from video: '620'
#
#   Now processing sequences from video: '621'
#     - Processing sequence 1970/2726 ('real_621_seq1')...
#
#   Now processing sequences from video: '622'
#
#   Now processing sequences from video: '623'
#
#   Now processing sequences from video: '624'
#
#   Now processing sequences from video: '625'
#
#   Now processing sequences from video: '626'
#     - Processing sequence 1980/2726 ('real_626_seq1')...
#
#   Now processing sequences from video: '627'
#
#   Now processing sequences from video: '628'
#
#   Now processing sequences from video: '629'
#
#   Now processing sequences from video: '630'
#
#   Now processing sequences from video: '631'
#     - Processing sequence 1990/2726 ('real_631_seq1')...
#
#   Now processing sequences from video: '632'
#
#   Now processing sequences from video: '633'
#
#   Now processing sequences from video: '634'
#
#   Now processing sequences from video: '635'
#
#   Now processing sequences from video: '636'
#     - Processing sequence 2000/2726 ('real_636_seq1')...
#
#   Now processing sequences from video: '637'
#
#   Now processing sequences from video: '638'
#
#   Now processing sequences from video: '639'
#
#   Now processing sequences from video: '640'
#
#   Now processing sequences from video: '641'
#     - Processing sequence 2010/2726 ('real_641_seq1')...
#
#   Now processing sequences from video: '642'
#
#   Now processing sequences from video: '643'
#
#   Now processing sequences from video: '644'
#
#   Now processing sequences from video: '645'
#
#   Now processing sequences from video: '646'
#     - Processing sequence 2020/2726 ('real_646_seq1')...
#
#   Now processing sequences from video: '647'
#
#   Now processing sequences from video: '648'
#
#   Now processing sequences from video: '649'
#
#   Now processing sequences from video: '650'
#
#   Now processing sequences from video: '651'
#     - Processing sequence 2030/2726 ('real_651_seq1')...
#
#   Now processing sequences from video: '652'
#
#   Now processing sequences from video: '653'
#
#   Now processing sequences from video: '654'
#
#   Now processing sequences from video: '655'
#
#   Now processing sequences from video: '656'
#     - Processing sequence 2040/2726 ('real_656_seq1')...
#
#   Now processing sequences from video: '657'
#
#   Now processing sequences from video: '658'
#
#   Now processing sequences from video: '659'
#
#   Now processing sequences from video: '660'
#
#   Now processing sequences from video: '661'
#     - Processing sequence 2050/2726 ('real_661_seq1')...
#
#   Now processing sequences from video: '662'
#
#   Now processing sequences from video: '663'
#
#   Now processing sequences from video: '664'
#
#   Now processing sequences from video: '665'
#
#   Now processing sequences from video: '666'
#     - Processing sequence 2060/2726 ('real_666_seq1')...
#
#   Now processing sequences from video: '667'
#
#   Now processing sequences from video: '668'
#
#   Now processing sequences from video: '669'
#
#   Now processing sequences from video: '670'
#
#   Now processing sequences from video: '671'
#     - Processing sequence 2070/2726 ('real_671_seq1')...
#
#   Now processing sequences from video: '672'
#
#   Now processing sequences from video: '673'
#
#   Now processing sequences from video: '674'
#
#   Now processing sequences from video: '675'
#
#   Now processing sequences from video: '676'
#     - Processing sequence 2080/2726 ('real_676_seq1')...
#
#   Now processing sequences from video: '677'
#
#   Now processing sequences from video: '678'
#
#   Now processing sequences from video: '679'
#
#   Now processing sequences from video: '680'
#
#   Now processing sequences from video: '681'
#     - Processing sequence 2090/2726 ('real_681_seq1')...
#
#   Now processing sequences from video: '682'
#
#   Now processing sequences from video: '683'
#
#   Now processing sequences from video: '684'
#
#   Now processing sequences from video: '685'
#
#   Now processing sequences from video: '686'
#     - Processing sequence 2100/2726 ('real_686_seq1')...
#
#   Now processing sequences from video: '687'
#
#   Now processing sequences from video: '688'
#
#   Now processing sequences from video: '689'
#
#   Now processing sequences from video: '690'
#
#   Now processing sequences from video: '691'
#     - Processing sequence 2110/2726 ('real_691_seq1')...
#
#   Now processing sequences from video: '692'
#
#   Now processing sequences from video: '693'
#
#   Now processing sequences from video: '694'
#
#   Now processing sequences from video: '695'
#
#   Now processing sequences from video: '696'
#     - Processing sequence 2120/2726 ('real_696_seq1')...
#
#   Now processing sequences from video: '697'
#
#   Now processing sequences from video: '698'
#
#   Now processing sequences from video: '699'
#
#   Now processing sequences from video: '700'
#
#   Now processing sequences from video: '701'
#     - Processing sequence 2130/2726 ('real_701_seq1')...
#
#   Now processing sequences from video: '702'
#
#   Now processing sequences from video: '703'
#
#   Now processing sequences from video: '704'
#
#   Now processing sequences from video: '705'
#
#   Now processing sequences from video: '706'
#     - Processing sequence 2140/2726 ('real_706_seq1')...
#
#   Now processing sequences from video: '707'
#
#   Now processing sequences from video: '708'
#
#   Now processing sequences from video: '709'
#
#   Now processing sequences from video: '710'
#
#   Now processing sequences from video: '711'
#     - Processing sequence 2150/2726 ('real_711_seq1')...
#
#   Now processing sequences from video: '712'
#
#   Now processing sequences from video: '713'
#
#   Now processing sequences from video: '714'
#
#   Now processing sequences from video: '715'
#
#   Now processing sequences from video: '716'
#     - Processing sequence 2160/2726 ('real_716_seq1')...
#
#   Now processing sequences from video: '717'
#
#   Now processing sequences from video: '718'
#
#   Now processing sequences from video: '719'
#
#   Now processing sequences from video: '720'
#
#   Now processing sequences from video: '721'
#     - Processing sequence 2170/2726 ('real_721_seq1')...
#
#   Now processing sequences from video: '722'
#
#   Now processing sequences from video: '723'
#
#   Now processing sequences from video: '724'
#
#   Now processing sequences from video: '725'
#
#   Now processing sequences from video: '726'
#     - Processing sequence 2180/2726 ('real_726_seq1')...
#
#   Now processing sequences from video: '727'
#
#   Now processing sequences from video: '728'
#
#   Now processing sequences from video: '729'
#
#   Now processing sequences from video: '730'
#
#   Now processing sequences from video: '731'
#     - Processing sequence 2190/2726 ('real_731_seq1')...
#
#   Now processing sequences from video: '732'
#
#   Now processing sequences from video: '733'
#
#   Now processing sequences from video: '734'
#
#   Now processing sequences from video: '735'
#
#   Now processing sequences from video: '736'
#     - Processing sequence 2200/2726 ('real_736_seq1')...
#
#   Now processing sequences from video: '737'
#
#   Now processing sequences from video: '738'
#
#   Now processing sequences from video: '739'
#
#   Now processing sequences from video: '740'
#
#   Now processing sequences from video: '741'
#     - Processing sequence 2210/2726 ('real_741_seq1')...
#
#   Now processing sequences from video: '742'
#
#   Now processing sequences from video: '743'
#
#   Now processing sequences from video: '744'
#
#   Now processing sequences from video: '745'
#
#   Now processing sequences from video: '746'
#     - Processing sequence 2220/2726 ('real_746_seq1')...
#
#   Now processing sequences from video: '747'
#
#   Now processing sequences from video: '748'
#
#   Now processing sequences from video: '749'
#
#   Now processing sequences from video: '750'
#
#   Now processing sequences from video: '751'
#     - Processing sequence 2230/2726 ('real_751_seq1')...
#
#   Now processing sequences from video: '752'
#
#   Now processing sequences from video: '753'
#
#   Now processing sequences from video: '754'
#
#   Now processing sequences from video: '755'
#
#   Now processing sequences from video: '756'
#     - Processing sequence 2240/2726 ('real_756_seq1')...
#
#   Now processing sequences from video: '757'
#
#   Now processing sequences from video: '758'
#
#   Now processing sequences from video: '759'
#
#   Now processing sequences from video: '760'
#
#   Now processing sequences from video: '761'
#     - Processing sequence 2250/2726 ('real_761_seq1')...
#
#   Now processing sequences from video: '762'
#
#   Now processing sequences from video: '763'
#
#   Now processing sequences from video: '764'
#
#   Now processing sequences from video: '765'
#
#   Now processing sequences from video: '766'
#     - Processing sequence 2260/2726 ('real_766_seq1')...
#
#   Now processing sequences from video: '767'
#
#   Now processing sequences from video: '768'
#
#   Now processing sequences from video: '769'
#
#   Now processing sequences from video: '770'
#
#   Now processing sequences from video: '771'
#     - Processing sequence 2270/2726 ('real_771_seq1')...
#
#   Now processing sequences from video: '772'
#
#   Now processing sequences from video: '773'
#
#   Now processing sequences from video: '774'
#
#   Now processing sequences from video: '775'
#
#   Now processing sequences from video: '776'
#     - Processing sequence 2280/2726 ('real_776_seq1')...
#
#   Now processing sequences from video: '777'
#
#   Now processing sequences from video: '778'
#
#   Now processing sequences from video: '779'
#
#   Now processing sequences from video: '780'
#
#   Now processing sequences from video: '781'
#     - Processing sequence 2290/2726 ('real_781_seq1')...
#
#   Now processing sequences from video: '782'
#
#   Now processing sequences from video: '783'
#
#   Now processing sequences from video: '784'
#
#   Now processing sequences from video: '785'
#
#   Now processing sequences from video: '786'
#     - Processing sequence 2300/2726 ('real_786_seq1')...
#
#   Now processing sequences from video: '787'
#
#   Now processing sequences from video: '788'
#
#   Now processing sequences from video: '789'
#
#   Now processing sequences from video: '790'
#
#   Now processing sequences from video: '791'
#     - Processing sequence 2310/2726 ('real_791_seq1')...
#
#   Now processing sequences from video: '792'
#
#   Now processing sequences from video: '793'
#
#   Now processing sequences from video: '794'
#
#   Now processing sequences from video: '795'
#
#   Now processing sequences from video: '796'
#     - Processing sequence 2320/2726 ('real_796_seq1')...
#
#   Now processing sequences from video: '797'
#
#   Now processing sequences from video: '798'
#
#   Now processing sequences from video: '799'
#
#   Now processing sequences from video: '800'
#
#   Now processing sequences from video: '801'
#     - Processing sequence 2330/2726 ('real_801_seq1')...
#
#   Now processing sequences from video: '802'
#
#   Now processing sequences from video: '803'
#
#   Now processing sequences from video: '804'
#
#   Now processing sequences from video: '805'
#
#   Now processing sequences from video: '806'
#     - Processing sequence 2340/2726 ('real_806_seq1')...
#
#   Now processing sequences from video: '807'
#
#   Now processing sequences from video: '808'
#
#   Now processing sequences from video: '809'
#
#   Now processing sequences from video: '810'
#
#   Now processing sequences from video: '811'
#     - Processing sequence 2350/2726 ('real_811_seq1')...
#
#   Now processing sequences from video: '812'
#
#   Now processing sequences from video: '813'
#
#   Now processing sequences from video: '814'
#
#   Now processing sequences from video: '815'
#
#   Now processing sequences from video: '816'
#     - Processing sequence 2360/2726 ('real_816_seq1')...
#
#   Now processing sequences from video: '817'
#
#   Now processing sequences from video: '818'
#
#   Now processing sequences from video: '819'
#
#   Now processing sequences from video: '820'
#
#   Now processing sequences from video: '821'
#     - Processing sequence 2370/2726 ('real_821_seq1')...
#
#   Now processing sequences from video: '822'
#
#   Now processing sequences from video: '823'
#
#   Now processing sequences from video: '824'
#
#   Now processing sequences from video: '825'
#
#   Now processing sequences from video: '826'
#     - Processing sequence 2380/2726 ('real_826_seq1')...
#
#   Now processing sequences from video: '827'
#
#   Now processing sequences from video: '828'
#
#   Now processing sequences from video: '829'
#
#   Now processing sequences from video: '830'
#
#   Now processing sequences from video: '831'
#     - Processing sequence 2390/2726 ('real_831_seq1')...
#
#   Now processing sequences from video: '832'
#
#   Now processing sequences from video: '833'
#
#   Now processing sequences from video: '834'
#
#   Now processing sequences from video: '835'
#
#   Now processing sequences from video: '836'
#     - Processing sequence 2400/2726 ('real_836_seq1')...
#
#   Now processing sequences from video: '837'
#
#   Now processing sequences from video: '838'
#
#   Now processing sequences from video: '839'
#
#   Now processing sequences from video: '840'
#
#   Now processing sequences from video: '841'
#     - Processing sequence 2410/2726 ('real_841_seq1')...
#
#   Now processing sequences from video: '842'
#
#   Now processing sequences from video: '843'
#
#   Now processing sequences from video: '844'
#
#   Now processing sequences from video: '845'
#
#   Now processing sequences from video: '846'
#     - Processing sequence 2420/2726 ('real_846_seq1')...
#
#   Now processing sequences from video: '847'
#
#   Now processing sequences from video: '848'
#
#   Now processing sequences from video: '849'
#
#   Now processing sequences from video: '850'
#
#   Now processing sequences from video: '851'
#     - Processing sequence 2430/2726 ('real_851_seq1')...
#
#   Now processing sequences from video: '852'
#
#   Now processing sequences from video: '853'
#
#   Now processing sequences from video: '854'
#
#   Now processing sequences from video: '855'
#
#   Now processing sequences from video: '856'
#     - Processing sequence 2440/2726 ('real_856_seq1')...
#
#   Now processing sequences from video: '857'
#
#   Now processing sequences from video: '858'
#
#   Now processing sequences from video: '859'
#
#   Now processing sequences from video: '860'
#
#   Now processing sequences from video: '861'
#     - Processing sequence 2450/2726 ('real_861_seq1')...
#
#   Now processing sequences from video: '862'
#
#   Now processing sequences from video: '863'
#
#   Now processing sequences from video: '864'
#
#   Now processing sequences from video: '865'
#
#   Now processing sequences from video: '866'
#     - Processing sequence 2460/2726 ('real_866_seq1')...
#
#   Now processing sequences from video: '867'
#
#   Now processing sequences from video: '868'
#
#   Now processing sequences from video: '869'
#
#   Now processing sequences from video: '870'
#
#   Now processing sequences from video: '871'
#     - Processing sequence 2470/2726 ('real_871_seq1')...
#
#   Now processing sequences from video: '872'
#
#   Now processing sequences from video: '873'
#
#   Now processing sequences from video: '874'
#
#   Now processing sequences from video: '875'
#
#   Now processing sequences from video: '876'
#     - Processing sequence 2480/2726 ('real_876_seq1')...
#
#   Now processing sequences from video: '877'
#
#   Now processing sequences from video: '878'
#
#   Now processing sequences from video: '879'
#
#   Now processing sequences from video: '880'
#
#   Now processing sequences from video: '881'
#     - Processing sequence 2490/2726 ('real_881_seq1')...
#
#   Now processing sequences from video: '882'
#
#   Now processing sequences from video: '883'
#
#   Now processing sequences from video: '884'
#
#   Now processing sequences from video: '885'
#
#   Now processing sequences from video: '886'
#     - Processing sequence 2500/2726 ('real_886_seq1')...
#
#   Now processing sequences from video: '887'
#
#   Now processing sequences from video: '888'
#
#   Now processing sequences from video: '889'
#
#   Now processing sequences from video: '890'
#
#   Now processing sequences from video: '891'
#     - Processing sequence 2510/2726 ('real_891_seq1')...
#
#   Now processing sequences from video: '892'
#
#   Now processing sequences from video: '893'
#
#   Now processing sequences from video: '894'
#
#   Now processing sequences from video: '895'
#
#   Now processing sequences from video: '896'
#     - Processing sequence 2520/2726 ('real_896_seq1')...
#
#   Now processing sequences from video: '897'
#
#   Now processing sequences from video: '898'
#
#   Now processing sequences from video: '899'
#
#   Now processing sequences from video: '900'
#
#   Now processing sequences from video: '901'
#     - Processing sequence 2530/2726 ('real_901_seq1')...
#
#   Now processing sequences from video: '902'
#
#   Now processing sequences from video: '903'
#
#   Now processing sequences from video: '904'
#
#   Now processing sequences from video: '905'
#
#   Now processing sequences from video: '906'
#     - Processing sequence 2540/2726 ('real_906_seq1')...
#
#   Now processing sequences from video: '907'
#
#   Now processing sequences from video: '908'
#
#   Now processing sequences from video: '909'
#
#   Now processing sequences from video: '910'
#
#   Now processing sequences from video: '911'
#     - Processing sequence 2550/2726 ('real_911_seq1')...
#
#   Now processing sequences from video: '912'
#
#   Now processing sequences from video: '913'
#
#   Now processing sequences from video: '914'
#
#   Now processing sequences from video: '915'
#
#   Now processing sequences from video: '916'
#     - Processing sequence 2560/2726 ('real_916_seq1')...
#
#   Now processing sequences from video: '917'
#
#   Now processing sequences from video: '918'
#
#   Now processing sequences from video: '919'
#
#   Now processing sequences from video: '920'
#
#   Now processing sequences from video: '921'
#     - Processing sequence 2570/2726 ('real_921_seq1')...
#
#   Now processing sequences from video: '922'
#
#   Now processing sequences from video: '923'
#
#   Now processing sequences from video: '924'
#
#   Now processing sequences from video: '925'
#
#   Now processing sequences from video: '926'
#     - Processing sequence 2580/2726 ('real_926_seq1')...
#
#   Now processing sequences from video: '927'
#
#   Now processing sequences from video: '928'
#
#   Now processing sequences from video: '929'
#
#   Now processing sequences from video: '930'
#
#   Now processing sequences from video: '931'
#     - Processing sequence 2590/2726 ('real_931_seq1')...
#
#   Now processing sequences from video: '932'
#
#   Now processing sequences from video: '933'
#
#   Now processing sequences from video: '934'
#
#   Now processing sequences from video: '935'
#
#   Now processing sequences from video: '936'
#     - Processing sequence 2600/2726 ('real_936_seq1')...
#
#   Now processing sequences from video: '937'
#
#   Now processing sequences from video: '938'
#
#   Now processing sequences from video: '939'
#
#   Now processing sequences from video: '940'
#
#   Now processing sequences from video: '941'
#     - Processing sequence 2610/2726 ('real_941_seq1')...
#
#   Now processing sequences from video: '942'
#
#   Now processing sequences from video: '943'
#
#   Now processing sequences from video: '944'
#
#   Now processing sequences from video: '945'
#
#   Now processing sequences from video: '946'
#     - Processing sequence 2620/2726 ('real_946_seq1')...
#
#   Now processing sequences from video: '947'
#
#   Now processing sequences from video: '948'
#
#   Now processing sequences from video: '949'
#
#   Now processing sequences from video: '950'
#
#   Now processing sequences from video: '951'
#     - Processing sequence 2630/2726 ('real_951_seq1')...
#
#   Now processing sequences from video: '952'
#
#   Now processing sequences from video: '953'
#
#   Now processing sequences from video: '954'
#
#   Now processing sequences from video: '955'
#
#   Now processing sequences from video: '956'
#     - Processing sequence 2640/2726 ('real_956_seq1')...
#
#   Now processing sequences from video: '957'
#
#   Now processing sequences from video: '958'
#
#   Now processing sequences from video: '959'
#
#   Now processing sequences from video: '960'
#
#   Now processing sequences from video: '961'
#     - Processing sequence 2650/2726 ('real_961_seq1')...
#
#   Now processing sequences from video: '962'
#
#   Now processing sequences from video: '963'
#
#   Now processing sequences from video: '964'
#
#   Now processing sequences from video: '965'
#
#   Now processing sequences from video: '966'
#     - Processing sequence 2660/2726 ('real_966_seq1')...
#
#   Now processing sequences from video: '967'
#
#   Now processing sequences from video: '968'
#
#   Now processing sequences from video: '969'
#
#   Now processing sequences from video: '970'
#
#   Now processing sequences from video: '971'
#     - Processing sequence 2670/2726 ('real_971_seq1')...
#
#   Now processing sequences from video: '972'
#
#   Now processing sequences from video: '973'
#
#   Now processing sequences from video: '974'
#
#   Now processing sequences from video: '975'
#
#   Now processing sequences from video: '976'
#     - Processing sequence 2680/2726 ('real_976_seq1')...
#
#   Now processing sequences from video: '977'
#
#   Now processing sequences from video: '978'
#
#   Now processing sequences from video: '979'
#
#   Now processing sequences from video: '980'
#
#   Now processing sequences from video: '981'
#     - Processing sequence 2690/2726 ('real_981_seq1')...
#
#   Now processing sequences from video: '982'
#
#   Now processing sequences from video: '983'
#
#   Now processing sequences from video: '984'
#
#   Now processing sequences from video: '985'
#
#   Now processing sequences from video: '986'
#     - Processing sequence 2700/2726 ('real_986_seq1')...
#
#   Now processing sequences from video: '987'
#
#   Now processing sequences from video: '988'
#
#   Now processing sequences from video: '989'
#
#   Now processing sequences from video: '990'
#
#   Now processing sequences from video: '991'
#     - Processing sequence 2710/2726 ('real_991_seq1')...
#
#   Now processing sequences from video: '992'
#
#   Now processing sequences from video: '993'
#
#   Now processing sequences from video: '994'
#
#   Now processing sequences from video: '995'
#
#   Now processing sequences from video: '996'
#     - Processing sequence 2720/2726 ('real_996_seq1')...
#
#   Now processing sequences from video: '997'
#
#   Now processing sequences from video: '998'
#
#   Now processing sequences from video: '999'
# --- Finished precomputing. Generated 0 new flow sequences. ---
#
# --- Starting Optical Flow Computation for FAKE sequences ---
# Attempting to generate flow for 2726 sequences...
#
#   Now processing sequences from video: 'pika-00414325-1dd0-5bdd-b9ea-3d4437400fc3'
#     - Processing sequence 1/2726 ('fake_pika-00414325-1dd0-5bdd-b9ea-3d4437400fc3_seq0')...
#
#   Now processing sequences from video: 'pika-007d8549-8b82-5534-80a9-2fea276607bb'
#     - Processing sequence 2/2726 ('fake_pika-007d8549-8b82-5534-80a9-2fea276607bb_seq0')...
#
#   Now processing sequences from video: 'pika-008bfe58-6f23-58f5-9905-df7f44c245a1'
#     - Processing sequence 3/2726 ('fake_pika-008bfe58-6f23-58f5-9905-df7f44c245a1_seq0')...
#     - Processing sequence 4/2726 ('fake_pika-008bfe58-6f23-58f5-9905-df7f44c245a1_seq1')...
#
#   Now processing sequences from video: 'pika-0099c2a9-a918-5da9-b2f8-b127801a566f'
#     - Processing sequence 5/2726 ('fake_pika-0099c2a9-a918-5da9-b2f8-b127801a566f_seq0')...
#
#   Now processing sequences from video: 'pika-00bd979d-8398-532f-b4c3-d272df73020e'
#
#   Now processing sequences from video: 'pika-00c04474-c352-55b2-88de-f4ae1b94ae8d'
#     - Processing sequence 10/2726 ('fake_pika-00c04474-c352-55b2-88de-f4ae1b94ae8d_seq1')...
#
#   Now processing sequences from video: 'pika-00f998e9-b8c4-5dd7-8f05-5c1de9084766'
#
#   Now processing sequences from video: 'pika-012be5bd-cccd-5b69-bf1a-a5a2b0c7d0b3'
#
#   Now processing sequences from video: 'pika-01394c8a-3f05-53e6-b0b7-f201251f0065'
#
#   Now processing sequences from video: 'pika-0148b431-f0c2-591b-aee4-d8d95cca5657'
#
#   Now processing sequences from video: 'pika-014b282a-3681-568c-bc55-02829c6459a4'
#
#   Now processing sequences from video: 'pika-0166958b-c41b-5e24-9724-ebdfaf0bb8f1'
#
#   Now processing sequences from video: 'pika-01670e1d-e777-50cd-9f31-ca433c22b4c7'
#     - Processing sequence 20/2726 ('fake_pika-01670e1d-e777-50cd-9f31-ca433c22b4c7_seq0')...
#
#   Now processing sequences from video: 'pika-01673c9a-37d6-59d7-b518-b31b74dc623e'
#
#   Now processing sequences from video: 'pika-01750d3c-3ff9-50ba-9872-6d9739cec24c'
#
#   Now processing sequences from video: 'pika-01836f05-ea75-583a-a516-d64839779257'
#
#   Now processing sequences from video: 'pika-018f2a12-ce49-5d82-9534-6d6fdf69cf0e'
#
#   Now processing sequences from video: 'pika-01a0c624-0c29-5509-854f-a9f904cfb7a0'
#
#   Now processing sequences from video: 'pika-01bf5b6f-f152-55aa-9c93-5bf64b04bc07'
#     - Processing sequence 30/2726 ('fake_pika-01bf5b6f-f152-55aa-9c93-5bf64b04bc07_seq1')...
#
#   Now processing sequences from video: 'pika-01f3e3a6-abab-53e1-b44a-d106a3495ee5'
#
#   Now processing sequences from video: 'pika-020a11d1-2572-5124-8bb1-1359311809df'
#
#   Now processing sequences from video: 'pika-020fcaa9-5861-5459-921f-33d5f47c5994'
#
#   Now processing sequences from video: 'pika-0217e036-2fa6-54df-ade5-158ac5f94f37'
#
#   Now processing sequences from video: 'pika-021deb0a-1159-54e6-89c6-7691fd6b358e'
#
#   Now processing sequences from video: 'pika-02320a57-3d96-5005-ac1e-c462cb05976f'
#     - Processing sequence 40/2726 ('fake_pika-02320a57-3d96-5005-ac1e-c462cb05976f_seq0')...
#
#   Now processing sequences from video: 'pika-024c8c2a-678f-53ca-8d0e-c12c3a10bed3'
#
#   Now processing sequences from video: 'pika-024ef029-6f2d-5f97-b746-fcf36d0c7ac7'
#
#   Now processing sequences from video: 'pika-02552e55-b141-5776-9537-6440df20afc4'
#
#   Now processing sequences from video: 'pika-025a97e2-4277-5559-ac3e-baea91a9db38'
#
#   Now processing sequences from video: 'pika-026294e5-adf5-55a8-a4f8-b84267bc824e'
#
#   Now processing sequences from video: 'pika-0270c2cb-510d-5b35-ad82-c71a51cf9bab'
#
#   Now processing sequences from video: 'pika-02756f11-0151-5d04-b2b8-67bd013eb601'
#     - Processing sequence 50/2726 ('fake_pika-02756f11-0151-5d04-b2b8-67bd013eb601_seq1')...
#
#   Now processing sequences from video: 'pika-0293e7d1-0fb6-521d-b722-d71040a85a8a'
#
#   Now processing sequences from video: 'pika-02968e4d-6ef3-5055-9c65-9afed72b8be6'
#
#   Now processing sequences from video: 'pika-029af826-5017-5176-974e-c9fcb760f4b5'
#
#   Now processing sequences from video: 'pika-02ba0e3a-56e9-552e-97b8-d99e6cbbc515'
#
#   Now processing sequences from video: 'pika-02d88a9a-5498-5fd4-94c0-619a474ad156'
#
#   Now processing sequences from video: 'pika-02e09c86-993a-5021-83e8-00e90d05ec60'
#     - Processing sequence 60/2726 ('fake_pika-02e09c86-993a-5021-83e8-00e90d05ec60_seq1')...
#
#   Now processing sequences from video: 'pika-02fcf3d2-48df-59a6-bfaf-6862d6809229'
#
#   Now processing sequences from video: 'pika-030a6749-aad9-5ca0-804d-c62ac2b31259'
#
#   Now processing sequences from video: 'pika-03319bc5-d25e-5c1e-99a1-923fe98c7dc8'
#
#   Now processing sequences from video: 'pika-0341856a-94f8-5f3a-b3b2-89b8526efb76'
#
#   Now processing sequences from video: 'pika-03702a73-2c9f-548b-9348-45a18d9598b0'
#
#   Now processing sequences from video: 'pika-039b163f-a639-55f1-ac39-4cfedda3ed69'
#     - Processing sequence 70/2726 ('fake_pika-039b163f-a639-55f1-ac39-4cfedda3ed69_seq1')...
#
#   Now processing sequences from video: 'pika-039b2e7f-d7c9-53b0-843a-0d904ff0cc1c'
#
#   Now processing sequences from video: 'pika-039fe4c6-a0d7-56b8-9fab-77324d5e980e'
#
#   Now processing sequences from video: 'pika-03df6952-31c6-52b5-a9e3-8f1184fbd732'
#
#   Now processing sequences from video: 'pika-03e9fc02-c70d-52e1-85ac-4dda311ba0c1'
#
#   Now processing sequences from video: 'pika-03ee043c-b2fd-5e26-be73-938fffd2803a'
#     - Processing sequence 80/2726 ('fake_pika-03ee043c-b2fd-5e26-be73-938fffd2803a_seq1')...
#
#   Now processing sequences from video: 'pika-04036bef-0980-5ce4-a25a-41cf4b1adfb8'
#
#   Now processing sequences from video: 'pika-040daad3-063a-5c4a-8a12-67aee4b36106'
#
#   Now processing sequences from video: 'pika-041c2b0c-cba6-5c69-8708-3bcbd2b184cf'
#
#   Now processing sequences from video: 'pika-041f639d-00e8-5f2a-a971-a238ac10ad3b'
#
#   Now processing sequences from video: 'pika-044a366b-2f1b-545b-b8d7-e57100a5bc8a'
#
#   Now processing sequences from video: 'pika-04652507-66ba-5f86-8a3f-62e96c7c349e'
#     - Processing sequence 90/2726 ('fake_pika-04652507-66ba-5f86-8a3f-62e96c7c349e_seq0')...
#
#   Now processing sequences from video: 'pika-04687077-62d0-5df2-9346-e1e81684556b'
#
#   Now processing sequences from video: 'pika-047031a0-6968-5dd7-b963-8000b9e4c58a'
#
#   Now processing sequences from video: 'pika-0478e1f6-13f5-53e4-9ed0-6b2ef17ae4cc'
#
#   Now processing sequences from video: 'pika-04a49ba4-d1ce-5c57-8899-25c9bd92bec4'
#
#   Now processing sequences from video: 'pika-04a8ab40-04ff-5170-a9d7-8fd3bd63ad40'
#
#   Now processing sequences from video: 'pika-04e3e832-af1c-5651-aba6-04927c5d5104'
#     - Processing sequence 100/2726 ('fake_pika-04e3e832-af1c-5651-aba6-04927c5d5104_seq0')...
#
#   Now processing sequences from video: 'pika-04f303c2-e2db-5474-b510-29f6a5e618f1'
#
#   Now processing sequences from video: 'pika-04fa13b4-d259-5f0c-9af3-cba27019dcaf'
#
#   Now processing sequences from video: 'pika-050a3669-5186-5547-84b3-9c74b66dd5a0'
#
#   Now processing sequences from video: 'pika-051d2c43-1f42-5cf8-9024-b0478fbb42ca'
#
#   Now processing sequences from video: 'pika-052e58f1-0afe-5ec4-aee0-cdd152c7c2f5'
#     - Processing sequence 110/2726 ('fake_pika-052e58f1-0afe-5ec4-aee0-cdd152c7c2f5_seq1')...
#
#   Now processing sequences from video: 'pika-057b5009-c7a2-5310-b530-47d1a72b2559'
#
#   Now processing sequences from video: 'pika-05939a6f-d4dc-587d-af13-b2a36d15c9ea'
#
#   Now processing sequences from video: 'pika-05cfd0b4-60a9-508c-a83f-a5582f02f488'
#
#   Now processing sequences from video: 'pika-05e0e246-05b1-50dc-a318-75daddef92ef'
#
#   Now processing sequences from video: 'pika-05e7345b-7b18-5a16-a699-ad89246dacdb'
#
#   Now processing sequences from video: 'pika-05ebdcef-8640-5d1d-80f2-18185bb675a6'
#     - Processing sequence 120/2726 ('fake_pika-05ebdcef-8640-5d1d-80f2-18185bb675a6_seq1')...
#
#   Now processing sequences from video: 'pika-06019fe6-b57e-5342-b356-5ddb033efcf5'
#
#   Now processing sequences from video: 'pika-060539a9-e85e-5295-8a42-a859e0b70151'
#
#   Now processing sequences from video: 'pika-06436fc3-8cdc-50b0-b146-48051a0d4ae1'
#
#   Now processing sequences from video: 'pika-06529756-8014-5574-9189-9c089b2edd6e'
#
#   Now processing sequences from video: 'pika-065ae8e7-7fc2-51c5-a926-2c9ea1d8cb80'
#
#   Now processing sequences from video: 'pika-065fdef6-4e3d-5ec4-9ca7-9681cc25f82d'
#
#   Now processing sequences from video: 'pika-066017ca-6d7b-53ab-92bf-2290a2788270'
#     - Processing sequence 130/2726 ('fake_pika-066017ca-6d7b-53ab-92bf-2290a2788270_seq1')...
#
#   Now processing sequences from video: 'pika-069327ab-f885-56f3-b8cb-37f1f255bae0'
#
#   Now processing sequences from video: 'pika-06a1ae34-7ced-52ac-a7b0-df01fa88f1dd'
#
#   Now processing sequences from video: 'pika-06a22983-73b9-5246-96e4-146cf9112ec6'
#
#   Now processing sequences from video: 'pika-06ac5751-d6da-59f4-a86b-9004ead57c47'
#
#   Now processing sequences from video: 'pika-06bbb405-f94d-5190-b754-5f3108722422'
#
#   Now processing sequences from video: 'pika-06c4fe96-c5f9-5c8a-a4a4-13d07184708f'
#     - Processing sequence 140/2726 ('fake_pika-06c4fe96-c5f9-5c8a-a4a4-13d07184708f_seq0')...
#
#   Now processing sequences from video: 'pika-06d4e2f9-38a5-57f5-99a2-63bd4a11fd50'
#
#   Now processing sequences from video: 'pika-06efaac4-21e6-502d-92ca-6d0d9c90bfc8'
#
#   Now processing sequences from video: 'pika-06f71962-a7ed-5214-83cd-2a17a1f2226f'
#
#   Now processing sequences from video: 'pika-06ff9882-f527-5dc6-8dd4-bdf6a89783b0'
#
# ...
#
#   Now processing sequences from video: 'pika-f4084dea-04ee-5c90-97ac-cb8b73eb6c94'
#
#   Now processing sequences from video: 'pika-f409a79f-46f1-5a95-b387-071e90cf259c'
#
#   Now processing sequences from video: 'pika-f426f43d-f4e7-5cbb-8b65-b7be0605a4d3'
#
#   Now processing sequences from video: 'pika-f4345614-fde1-5749-9748-91a219c61a28'
#
#   Now processing sequences from video: 'pika-f43966ae-2eab-5cc0-910b-88dc4268cbc2'
#     - Processing sequence 2460/2726 ('fake_pika-f43966ae-2eab-5cc0-910b-88dc4268cbc2_seq1')...
#
#   Now processing sequences from video: 'pika-f441f119-6f01-5439-a6e8-32cdbeddf42f'
#
#   Now processing sequences from video: 'pika-f448c24a-f6df-53fc-a3d3-3b1a8f32cd9d'
#
#   Now processing sequences from video: 'pika-f464cea5-0cc5-5a54-b64e-b84b149f44da'
#
#   Now processing sequences from video: 'pika-f499b7ac-28a3-5789-a2c0-f8c025b98deb'
#
#   Now processing sequences from video: 'pika-f4c7647b-ba6b-56b1-8b11-e9d389fac491'
#
#   Now processing sequences from video: 'pika-f4cc019b-6303-51a8-93aa-6cfb52435e29'
#     - Processing sequence 2470/2726 ('fake_pika-f4cc019b-6303-51a8-93aa-6cfb52435e29_seq0')...
#
#   Now processing sequences from video: 'pika-f4f27bf3-91a5-5e6d-8438-416e7f43723e'
#
#   Now processing sequences from video: 'pika-f5117a59-cc7f-5e54-8f8a-a54c464c0cac'
#
#   Now processing sequences from video: 'pika-f56a3bec-0571-575c-abfd-10e023d6adf9'
#
#   Now processing sequences from video: 'pika-f570a5d2-5ac1-5844-9f74-678b2d712610'
#
#   Now processing sequences from video: 'pika-f577edc5-66c7-585b-8d2b-838a26863c66'
#     - Processing sequence 2480/2726 ('fake_pika-f577edc5-66c7-585b-8d2b-838a26863c66_seq1')...
#
#   Now processing sequences from video: 'pika-f5809f0e-0d54-5f1a-915f-0085693ab3c5'
#
#   Now processing sequences from video: 'pika-f5b39b83-8647-5607-9daf-1fd3d93dd098'
#
#   Now processing sequences from video: 'pika-f5b98413-e94d-5df2-ba97-cce8eb4463d8'
#
#   Now processing sequences from video: 'pika-f5cff3d8-9795-5018-8135-ddbe0813e0d4'
#
#   Now processing sequences from video: 'pika-f5df272a-1237-53bc-9633-cf42e275ed64'
#
#   Now processing sequences from video: 'pika-f5ea8ae0-36b4-550f-9bbd-d9cdabd71db5'
#     - Processing sequence 2490/2726 ('fake_pika-f5ea8ae0-36b4-550f-9bbd-d9cdabd71db5_seq0')...
#
#   Now processing sequences from video: 'pika-f60c54b6-4179-5bd7-9d20-e5f1fb2174d5'
#
#   Now processing sequences from video: 'pika-f633cf36-b065-5771-a7c0-95d7d40dd314'
#
#   Now processing sequences from video: 'pika-f647a258-7693-59d9-846c-9e5c3a5b9104'
#
#   Now processing sequences from video: 'pika-f64c982b-f58b-5fb8-9316-7732903b8708'
#
#   Now processing sequences from video: 'pika-f68f85ca-4e20-5721-8142-6dc5e3b3f425'
#     - Processing sequence 2500/2726 ('fake_pika-f68f85ca-4e20-5721-8142-6dc5e3b3f425_seq0')...
#
#   Now processing sequences from video: 'pika-f69ade4f-35d3-5e84-85d9-892d83b4f476'
#
#   Now processing sequences from video: 'pika-f69f1b15-2f38-5a3c-a659-feeafca792ae'
#
#   Now processing sequences from video: 'pika-f6a30d09-dffb-5743-b99d-c1510822c4b2'
#
#   Now processing sequences from video: 'pika-f6dcb923-b59e-521f-80a0-04cbdd2b3c48'
#
#   Now processing sequences from video: 'pika-f6e4d2cf-e496-5372-a029-31c8f8041635'
#
#   Now processing sequences from video: 'pika-f6eeedea-9f23-51e5-858c-87e16cf571fd'
#
#   Now processing sequences from video: 'pika-f7086394-8be2-57b2-9ec9-aab27507b1a7'
#     - Processing sequence 2510/2726 ('fake_pika-f7086394-8be2-57b2-9ec9-aab27507b1a7_seq0')...
#
#   Now processing sequences from video: 'pika-f714cddb-e3c8-5de0-b7e0-3f67e5aafbbe'
#
#   Now processing sequences from video: 'pika-f71bc78a-699c-53b2-9b74-3f37da4b5adb'
#
#   Now processing sequences from video: 'pika-f72648af-d590-5d56-b41b-f0877baa4a52'
#
#   Now processing sequences from video: 'pika-f72c1ff0-4b6d-58e6-b463-4ed376d7d88e'
#
#   Now processing sequences from video: 'pika-f74db90c-269a-5473-9721-5f72be471d59'
#     - Processing sequence 2520/2726 ('fake_pika-f74db90c-269a-5473-9721-5f72be471d59_seq0')...
#
#   Now processing sequences from video: 'pika-f764aa54-c786-5c96-8548-c34a14b2dc87'
#
#   Now processing sequences from video: 'pika-f76e564b-1a0c-564e-b004-8ab11e2321f3'
#
#   Now processing sequences from video: 'pika-f77856c9-7299-5dbb-a879-1366665088b6'
#
#   Now processing sequences from video: 'pika-f783edb5-af46-5dee-aad0-5e7ec1d562f3'
#
#   Now processing sequences from video: 'pika-f7a13e71-30d4-5d30-99a0-0f88387b8b63'
#     - Processing sequence 2530/2726 ('fake_pika-f7a13e71-30d4-5d30-99a0-0f88387b8b63_seq0')...
#
#   Now processing sequences from video: 'pika-f7b491e2-9fd2-5d33-8563-140e8a0cebb4'
#
#   Now processing sequences from video: 'pika-f7d6fe45-770c-5dd8-82aa-c29fee6f6d0e'
#
#   Now processing sequences from video: 'pika-f803d006-bae4-542c-bae5-0a1c66720099'
#
#   Now processing sequences from video: 'pika-f8112352-abd2-5351-9e4a-e25aafa36670'
#
#   Now processing sequences from video: 'pika-f814ac19-f697-5fd8-9281-366200f701b6'
#     - Processing sequence 2540/2726 ('fake_pika-f814ac19-f697-5fd8-9281-366200f701b6_seq1')...
#
#   Now processing sequences from video: 'pika-f8167dfa-d6fd-5c38-b88d-424c6db4dcf0'
#
#   Now processing sequences from video: 'pika-f8182f13-a989-508e-8cb6-0890f618866b'
#
#   Now processing sequences from video: 'pika-f81e6014-c6b3-55e2-a949-426e0b30ded4'
#
#   Now processing sequences from video: 'pika-f83f1009-69fc-52f5-b018-8ea6cdc61fe1'
#
#   Now processing sequences from video: 'pika-f8469cf9-d7d4-57f2-8dcc-e04181dd42ad'
#
#   Now processing sequences from video: 'pika-f84a203b-43a7-53b7-bbcf-3b1a5b702a97'
#     - Processing sequence 2550/2726 ('fake_pika-f84a203b-43a7-53b7-bbcf-3b1a5b702a97_seq0')...
#
#   Now processing sequences from video: 'pika-f84ab9c3-f922-5b0b-b15b-3a963f448137'
#
#   Now processing sequences from video: 'pika-f85b9cf8-63c1-5c93-a1bd-37e1fe7bc890'
#
#   Now processing sequences from video: 'pika-f8966b0c-f178-5e5d-bc16-dc5415f3ab6a'
#
#   Now processing sequences from video: 'pika-f8987fbe-9b11-51a5-a54d-1317e778c108'
#
#   Now processing sequences from video: 'pika-f8bbd9f2-9dcc-5a80-9f0c-408c85dbded9'
#     - Processing sequence 2560/2726 ('fake_pika-f8bbd9f2-9dcc-5a80-9f0c-408c85dbded9_seq0')...
#
#   Now processing sequences from video: 'pika-f8ed79a0-2d8d-509f-9ce0-c9e520421311'
#
#   Now processing sequences from video: 'pika-f8f1a1e7-3dd6-5347-8deb-90573b320985'
#
#   Now processing sequences from video: 'pika-f8f1ba54-2ef1-5a5f-99f9-b1db00d41315'
#
#   Now processing sequences from video: 'pika-f9121cf3-19ca-5f18-be55-e40178b2cfa4'
#
#   Now processing sequences from video: 'pika-f91d30ce-d2c2-502b-bc2d-00c71b9f289c'
#     - Processing sequence 2570/2726 ('fake_pika-f91d30ce-d2c2-502b-bc2d-00c71b9f289c_seq1')...
#
#   Now processing sequences from video: 'pika-f925ca7a-b70c-5573-b473-cde21923a6ac'
#
#   Now processing sequences from video: 'pika-f932aa40-5548-571a-ac79-d0f581a64eb2'
#
#   Now processing sequences from video: 'pika-f933e10f-c87c-599e-92f4-9e7ad0eb6aec'
#
#   Now processing sequences from video: 'pika-f941ef03-7223-5f55-8442-7965bc2fd638'
#
#   Now processing sequences from video: 'pika-f94e9f82-54a8-5be7-8035-357059517b33'
#
#   Now processing sequences from video: 'pika-f95586ba-69e5-5019-9b8d-260032873d84'
#     - Processing sequence 2580/2726 ('fake_pika-f95586ba-69e5-5019-9b8d-260032873d84_seq0')...
#
#   Now processing sequences from video: 'pika-f9641faf-b914-59b0-b451-041d1486bace'
#
#   Now processing sequences from video: 'pika-f96c594d-ad62-55dd-8c1d-aea6f7a90165'
#
#   Now processing sequences from video: 'pika-f98d4db9-b30c-57ee-a141-94299c493e54'
#
#   Now processing sequences from video: 'pika-f9b487b6-77ca-5bad-aa06-4c18f057f388'
#
#   Now processing sequences from video: 'pika-f9c1ab75-a057-592d-a318-a5a0979f3f3f'
#
#   Now processing sequences from video: 'pika-f9f3a389-65ba-5b86-a097-e7078a91280b'
#
#   Now processing sequences from video: 'pika-f9fbcea8-25b3-59dd-a280-f3cde405f1db'
#     - Processing sequence 2590/2726 ('fake_pika-f9fbcea8-25b3-59dd-a280-f3cde405f1db_seq0')...
#
#   Now processing sequences from video: 'pika-f9ff250e-7f33-5e2c-951a-9aaf63916c8e'
#
#   Now processing sequences from video: 'pika-fa34ad40-d71d-51e6-a56c-236d7296d2aa'
#
#   Now processing sequences from video: 'pika-fa390199-691c-5a5b-95a4-2f0afa84aff1'
#
#   Now processing sequences from video: 'pika-fa4357e4-6bd0-508b-b451-fd0edf708846'
#
#   Now processing sequences from video: 'pika-fa4d9db4-b4ba-55fc-b28e-099f1d2cd803'
#
#   Now processing sequences from video: 'pika-fa57f851-3efa-5725-a93e-37025f93bcf8'
#     - Processing sequence 2600/2726 ('fake_pika-fa57f851-3efa-5725-a93e-37025f93bcf8_seq1')...
#
#   Now processing sequences from video: 'pika-fa6d15a8-5929-5b4c-90c9-650cf20d41d3'
#
#   Now processing sequences from video: 'pika-fa8c924f-3690-5874-8af2-d5e2393986d3'
#
#   Now processing sequences from video: 'pika-fa9af352-f457-503b-80af-5e42beecf9f4'
#
#   Now processing sequences from video: 'pika-fabc8881-bb8d-5e8e-986f-d43b7184639c'
#
#   Now processing sequences from video: 'pika-fadd349c-9306-528d-9d11-25cd7c07a68e'
#
#   Now processing sequences from video: 'pika-fae2c171-ef82-5e19-a7e4-8eb260b14cf6'
#     - Processing sequence 2610/2726 ('fake_pika-fae2c171-ef82-5e19-a7e4-8eb260b14cf6_seq1')...
#
#   Now processing sequences from video: 'pika-fb267554-65f6-5ee8-86f1-bbc5adc16096'
#
#   Now processing sequences from video: 'pika-fb299888-7a58-5fda-80e7-aa9fccc35c9f'
#
#   Now processing sequences from video: 'pika-fb2d87ba-ca2b-588a-9d01-97fc2a0a7663'
#
#   Now processing sequences from video: 'pika-fb2ff46b-f228-5cd7-b85b-a335e6e28ac4'
#
#   Now processing sequences from video: 'pika-fb48bfb2-bc8a-5e8d-8920-bb9cc33e05c8'
#
#   Now processing sequences from video: 'pika-fb62dc7a-a2ad-5997-ae4b-b815b7f1c033'
#     - Processing sequence 2620/2726 ('fake_pika-fb62dc7a-a2ad-5997-ae4b-b815b7f1c033_seq1')...
#
#   Now processing sequences from video: 'pika-fb6c3288-cf41-52c5-a52a-de7a639ddb9e'
#
#   Now processing sequences from video: 'pika-fbb7c42f-80b1-5eb2-8dd5-0adf4806b3d0'
#
#   Now processing sequences from video: 'pika-fbbd6288-0b20-51fc-88ce-b50ac5ac2a72'
#
#   Now processing sequences from video: 'pika-fbda6b9b-d33d-5e3b-b368-4e27bcb43dc3'
#
#   Now processing sequences from video: 'pika-fbdbf1f9-a668-5fac-ab30-880dcd2bfa6e'
#
#   Now processing sequences from video: 'pika-fbe21ece-ef5e-5b8c-8732-573d613cc5fe'
#     - Processing sequence 2630/2726 ('fake_pika-fbe21ece-ef5e-5b8c-8732-573d613cc5fe_seq1')...
#
#   Now processing sequences from video: 'pika-fbe7fca0-9d98-51ce-8c2a-ebf53e2292ba'
#
#   Now processing sequences from video: 'pika-fbfe290d-048c-5bcc-8b19-e1684539d250'
#
#   Now processing sequences from video: 'pika-fc11bb77-6760-59af-a2fe-0de0f9831c73'
#
#   Now processing sequences from video: 'pika-fc1626a6-9524-57e7-ace3-bb912663780d'
#
#   Now processing sequences from video: 'pika-fc4de953-23f3-5cbb-9e68-03b7b2539961'
#     - Processing sequence 2640/2726 ('fake_pika-fc4de953-23f3-5cbb-9e68-03b7b2539961_seq1')...
#
#   Now processing sequences from video: 'pika-fc584d7e-df5e-5616-812d-db72e651dcc5'
#
#   Now processing sequences from video: 'pika-fc5ff409-3933-52f4-9503-7073316c1380'
#
#   Now processing sequences from video: 'pika-fc6ec803-6464-5491-af87-775df3f2e3f1'
#
#   Now processing sequences from video: 'pika-fc8a1779-2c7e-5640-bc11-c2d768f7d620'
#
#   Now processing sequences from video: 'pika-fc962f37-a668-5e84-ba25-6113cc9e0c91'
#
#   Now processing sequences from video: 'pika-fcd4394a-ac28-508e-9878-9520848f51d8'
#
#   Now processing sequences from video: 'pika-fd0b9766-c69a-5dbb-a043-d2841a1ba002'
#     - Processing sequence 2650/2726 ('fake_pika-fd0b9766-c69a-5dbb-a043-d2841a1ba002_seq0')...
#
#   Now processing sequences from video: 'pika-fd0ba730-92a9-5f6a-bfc7-6b030a18d067'
#
#   Now processing sequences from video: 'pika-fd3eddd1-8289-529e-9413-0a5c711b4f99'
#
#   Now processing sequences from video: 'pika-fd6f5c67-3f3a-58d1-abc3-53d9ab5e44fe'
#
#   Now processing sequences from video: 'pika-fd78e98f-e0cd-5ef2-92e7-b2323c7526bb'
#
#   Now processing sequences from video: 'pika-fd88bdd8-1012-5d82-adee-e0708a6affe3'
#
#   Now processing sequences from video: 'pika-fd8bd9a1-7b06-5c95-8ad3-eca2dfd4db32'
#     - Processing sequence 2660/2726 ('fake_pika-fd8bd9a1-7b06-5c95-8ad3-eca2dfd4db32_seq1')...
#
#   Now processing sequences from video: 'pika-fd919dc5-3d37-50e5-9842-707be89ffe66'
#
#   Now processing sequences from video: 'pika-fd9c6c42-77c1-53fe-ab9c-d0203f1c8fbf'
#
#   Now processing sequences from video: 'pika-fdb41157-30a5-5465-82bd-fc9a28a604c4'
#
#   Now processing sequences from video: 'pika-fdba3ab9-0bb3-57b6-9f39-a63ee09bf6ee'
#
#   Now processing sequences from video: 'pika-fdbf1e6e-b556-5108-97f7-cf36a8f145ce'
#
#   Now processing sequences from video: 'pika-fdcce261-3a1b-5009-ad38-5c02712b07aa'
#     - Processing sequence 2670/2726 ('fake_pika-fdcce261-3a1b-5009-ad38-5c02712b07aa_seq1')...
#
#   Now processing sequences from video: 'pika-fe04a76c-255c-5dcb-b059-1d8bfc093312'
#
#   Now processing sequences from video: 'pika-fe12c0a9-dd74-5b26-b0c8-9844fdbe8146'
#
#   Now processing sequences from video: 'pika-fe3b1a3d-6491-5b63-a899-c93cf127ddf6'
#
#   Now processing sequences from video: 'pika-fe69c568-b192-5ba9-b0a6-6ce7c626c8a4'
#
#   Now processing sequences from video: 'pika-fe7b4cee-26b0-553f-8388-c90da3552c4a'
#
#   Now processing sequences from video: 'pika-fe7d8d60-c536-54f1-82d0-a984c875c4c0'
#     - Processing sequence 2680/2726 ('fake_pika-fe7d8d60-c536-54f1-82d0-a984c875c4c0_seq0')...
#
#   Now processing sequences from video: 'pika-fe84b193-9d9f-5057-9f52-3014fcdf1088'
#
#   Now processing sequences from video: 'pika-fe8e0b8e-dde3-509d-9a14-76a23e4d1ac8'
#
#   Now processing sequences from video: 'pika-fe970009-a3b7-521b-bba7-ede03b24a445'
#
#   Now processing sequences from video: 'pika-fe9abaf4-9dfe-5c3b-934a-ef2fdd3db185'
#
#   Now processing sequences from video: 'pika-feb1af50-53a4-5496-b9cb-d524c5fe3e54'
#
#   Now processing sequences from video: 'pika-fecf74a3-cb99-552e-bea8-6974a22b4c27'
#     - Processing sequence 2690/2726 ('fake_pika-fecf74a3-cb99-552e-bea8-6974a22b4c27_seq0')...
#
#   Now processing sequences from video: 'pika-fed6304f-b20e-5ecf-8c21-a5721350d8bd'
#
#   Now processing sequences from video: 'pika-fedf1ecb-fe21-57bc-b5b4-d2c23befb3b5'
#
#   Now processing sequences from video: 'pika-fee8fca4-f88c-5926-8c87-725e2138d8b2'
#
#   Now processing sequences from video: 'pika-fef4e526-884d-52cf-b418-9e035f6a15f7'
#
#   Now processing sequences from video: 'pika-ff20bee9-76a3-5e62-86ec-aab74bf8a71a'
#     - Processing sequence 2700/2726 ('fake_pika-ff20bee9-76a3-5e62-86ec-aab74bf8a71a_seq1')...
#
#   Now processing sequences from video: 'pika-ff337487-8706-5abb-9e3f-9d699be72d20'
#
#   Now processing sequences from video: 'pika-ff56838d-2189-59f2-ae6f-8888d11f03d1'
#
#   Now processing sequences from video: 'pika-ff5f73a6-d1d6-5e19-a6c8-a7389d18d4d8'
#
#   Now processing sequences from video: 'pika-ff693eb6-524c-582b-93e6-ee9dccc51bf0'
#
#   Now processing sequences from video: 'pika-ff746a9b-d43d-5581-89d4-3be6b0ec39d9'
#
#   Now processing sequences from video: 'pika-ff7d8947-a58f-5040-a854-463de010ebb5'
#     - Processing sequence 2710/2726 ('fake_pika-ff7d8947-a58f-5040-a854-463de010ebb5_seq1')...
#
#   Now processing sequences from video: 'pika-ff81dfb0-7b07-5d56-bd53-5308c4ab2fc7'
#
#   Now processing sequences from video: 'pika-ff85437d-7f35-58d1-9014-8585722bc995'
#
#   Now processing sequences from video: 'pika-ff8ddcaf-69df-53ee-b8fb-a51558bc37f6'
#
#   Now processing sequences from video: 'pika-ff9f4da4-a06e-5c37-accb-5946943a72b7'
#
#   Now processing sequences from video: 'pika-ffbe75cc-f8b8-53bd-843f-45e253322b07'
#
#   Now processing sequences from video: 'pika-ffc9a92c-5b44-58c9-a806-33d7153a6d16'
#     - Processing sequence 2720/2726 ('fake_pika-ffc9a92c-5b44-58c9-a806-33d7153a6d16_seq1')...
#
#   Now processing sequences from video: 'pika-ffd2a187-de4f-5140-80cb-e93eeacb989c'
#
#   Now processing sequences from video: 'pika-ffdd6df6-049f-594e-bc2a-8311116c357c'
#
#   Now processing sequences from video: 'pika-ffe781d3-fa0b-5568-be66-7069fc129521'
# --- Finished precomputing. Generated 993 new flow sequences. ---
#
# --- Optical Flow Preprocessing is DONE ---

# %% [markdown]
# Processing Flow for New dataset

# %%
# === SCRIPT TO PROCESS A SUBSET OF DATA: SELECT FIRST 10 CHUNKS, BALANCE, AND COMPUTE FLOW ===

import os
import glob
import time
import shutil
import cv2
import numpy as np
import math
import re
import gc
import random
from pathlib import Path
from google.colab import drive
from collections import defaultdict
import torch

# --- Configuration ---
# 1. The Drive folder where ALL your frame chunks are stored
DRIVE_ZIPPED_FRAMES_DIR = "/content/drive/MyDrive/New_Dataset"

# 2. Number of chunks to select PER CLASS
NUM_CHUNKS_TO_SELECT = 10

# 3. Parameters for sequence creation
SEQUENCE_LENGTH = 30
STEP_SIZE = 30

# 4. The NEW output directory on Drive for this smaller experiment
DRIVE_OUTPUT_DIR = "/content/drive/MyDrive/New_Dataset"

# 5. Local directories
LOCAL_TEMP_ZIPS_DIR = "/content/temp_selected_zips"
LOCAL_FRAMES_DIR = "/content/local_selected_frames"
# --- End of Configuration ---


# --- Mount Drive and Setup Directories ---
drive.mount('/content/drive', force_remount=True)
os.makedirs(DRIVE_OUTPUT_DIR, exist_ok=True)
os.makedirs(LOCAL_TEMP_ZIPS_DIR, exist_ok=True)
LOCAL_REAL_FRAMES_DIR = os.path.join(LOCAL_FRAMES_DIR, "real_frames")
LOCAL_FAKE_FRAMES_DIR = os.path.join(LOCAL_FRAMES_DIR, "fake_frames")
os.makedirs(LOCAL_REAL_FRAMES_DIR, exist_ok=True)
os.makedirs(LOCAL_FAKE_FRAMES_DIR, exist_ok=True)
print(f"Precomputed optical flow will be saved to: {DRIVE_OUTPUT_DIR}")


# --- Helper Functions (Identical to your original script) ---
def group_frames_by_video(frame_paths, class_label_for_debug=""):
    # ... (This function remains the same) ...
    video_groups = defaultdict(list)
    for path_str in frame_paths:
        stem = Path(str(path_str)).stem
        # Simplified regex to be more robust
        match = re.match(r'^(.*?)_frame_(\d+)', stem)
        if match:
            video_stem = match.group(1)
        else: # Fallback for different naming
            video_stem = "_".join(stem.split('_')[:-2])
        video_groups[video_stem].append(str(path_str))
    for stem_key in list(video_groups.keys()):
        try:
            video_groups[stem_key] = sorted(video_groups[stem_key], key=lambda x: int(Path(x).stem.split('_')[-1]))
        except: video_groups[stem_key] = sorted(video_groups[stem_key])
    print(f"  Grouped {len(frame_paths)} frames into {len(video_groups)} video groups for '{class_label_for_debug}'.")
    return video_groups

def compute_optical_flow_for_one_sequence(bgr_frames_list, target_sequence_length):
    # ... (This function remains the same) ...
    flow_features_for_seq = [np.array([0.0, 0.0], dtype=np.float32)]
    for i in range(len(bgr_frames_list) - 1):
        try:
            prev_gray = cv2.cvtColor(bgr_frames_list[i], cv2.COLOR_BGR2GRAY)
            curr_gray = cv2.cvtColor(bgr_frames_list[i+1], cv2.COLOR_BGR2GRAY)
            flow_cv = cv2.calcOpticalFlowFarneback(prev_gray, curr_gray, None, 0.5, 3, 15, 3, 5, 1.2, 0)
            magnitude = np.sqrt(flow_cv[..., 0]**2 + flow_cv[..., 1]**2)
            flow_features_for_seq.append(np.array([np.mean(magnitude), np.var(magnitude)], dtype=np.float32))
        except Exception:
            flow_features_for_seq.append(np.array([0.0, 0.0], dtype=np.float32))
    return torch.tensor(np.array(flow_features_for_seq), dtype=torch.float32)

def preprocess_and_save_flow(all_sequences_to_process, save_dir, sequence_len):
    # ... (This function remains the same) ...
    total_sequences_generated_this_run = 0
    print(f"Attempting to generate flow for {len(all_sequences_to_process)} sequences...")
    last_video_stem_processed = None
    for seq_idx, (frame_paths, sequence_identifier) in enumerate(all_sequences_to_process):
        current_video_stem = "_".join(sequence_identifier.split('_')[1:-1])
        if current_video_stem != last_video_stem_processed:
            print(f"\n  Now processing sequences from video: '{current_video_stem}'")
            last_video_stem_processed = current_video_stem
        save_path = os.path.join(save_dir, f"{sequence_identifier}_flow.pt")
        if os.path.exists(save_path): continue
        seq_bgr_frames = [cv2.imread(fp) for fp in frame_paths if cv2.imread(fp) is not None]
        if len(seq_bgr_frames) == sequence_len:
            flow_tensor = compute_optical_flow_for_one_sequence(seq_bgr_frames, sequence_len)
            if flow_tensor is not None and flow_tensor.shape == (sequence_len, 2):
                torch.save(flow_tensor, save_path)
                total_sequences_generated_this_run += 1
    print(f"--- Finished precomputing. Generated {total_sequences_generated_this_run} new flow sequences. ---")


# --- Main Execution Block ---
if __name__ == '__main__':
    print("--- Starting Data Subsetting and Optical Flow Preprocessing ---")

    # --- Step 1: Select, Copy, and Unzip the FIRST 10 Chunks of Data ---
    print("\n--- Step 1: Preparing Local Dataset from the first 10 chunks per class ---")

    # --- Process REAL Frames ---
    print("\n  Processing REAL frame chunks...")
    all_real_chunks = sorted(glob.glob(os.path.join(DRIVE_ZIPPED_FRAMES_DIR, "real_frames_chunk_*.zip")))
    if not all_real_chunks:
        print("  Warning: No 'real_frames' chunks found.")
        selected_real_chunks = []
    else:
        # --- THIS IS THE KEY CHANGE ---
        # Select the first N chunks from the sorted list instead of a random sample
        selected_real_chunks = all_real_chunks[:NUM_CHUNKS_TO_SELECT]

    print(f"  Selected the following {len(selected_real_chunks)} chunks to process:")
    for path in selected_real_chunks: print(f"    - {Path(path).name}")

    for chunk_path in selected_real_chunks:
        shutil.copy(chunk_path, LOCAL_TEMP_ZIPS_DIR)

    for zip_path in glob.glob(os.path.join(LOCAL_TEMP_ZIPS_DIR, "real_frames_chunk_*.zip")):
        # !unzip -q -o "{zip_path}" -d "{LOCAL_REAL_FRAMES_DIR}"
    shutil.rmtree(LOCAL_TEMP_ZIPS_DIR) # Clean up after real
    os.makedirs(LOCAL_TEMP_ZIPS_DIR)  # Recreate for fake

    # --- Process FAKE Frames ---
    print("\n  Processing FAKE frame chunks...")
    all_fake_chunks = sorted(glob.glob(os.path.join(DRIVE_ZIPPED_FRAMES_DIR, "fake_frames_chunk_*.zip")))
    if not all_fake_chunks:
        print("  Warning: No 'fake_frames' chunks found.")
        selected_fake_chunks = []
    else:
        # --- THIS IS THE KEY CHANGE ---
        selected_fake_chunks = all_fake_chunks[:NUM_CHUNKS_TO_SELECT]

    print(f"  Selected the following {len(selected_fake_chunks)} chunks to process:")
    for path in selected_fake_chunks: print(f"    - {Path(path).name}")

    for chunk_path in selected_fake_chunks:
        shutil.copy(chunk_path, LOCAL_TEMP_ZIPS_DIR)

    for zip_path in glob.glob(os.path.join(LOCAL_TEMP_ZIPS_DIR, "fake_frames_chunk_*.zip")):
        # !unzip -q -o "{zip_path}" -d "{LOCAL_FAKE_FRAMES_DIR}"
    shutil.rmtree(LOCAL_TEMP_ZIPS_DIR) # Final cleanup

    # --- Step 2: Load Frames and Create Sequences (Logic is the same) ---
    print("\n--- Step 2: Loading frames and creating sequences from the local subset ---")
    all_real_frame_paths = sorted(glob.glob(os.path.join(LOCAL_REAL_FRAMES_DIR, '*.jpg')))
    all_fake_frame_paths = sorted(glob.glob(os.path.join(LOCAL_FAKE_FRAMES_DIR, '*.jpg')))

    # ... (The rest of the script for grouping, sequencing, balancing, and flow computation is identical) ...
    real_video_groups = group_frames_by_video(all_real_frame_paths, "real")
    fake_video_groups = group_frames_by_video(all_fake_frame_paths, "fake")

    all_sequences_info = []
    for video_stem, frames_list in real_video_groups.items():
        for i in range(0, len(frames_list) - SEQUENCE_LENGTH + 1, STEP_SIZE):
            seq_paths = frames_list[i : i + SEQUENCE_LENGTH]
            if len(seq_paths) == SEQUENCE_LENGTH:
                seq_id = f"real_{video_stem}_seq{i//STEP_SIZE}"
                all_sequences_info.append((seq_paths, seq_id, "real"))
    for video_stem, frames_list in fake_video_groups.items():
        for i in range(0, len(frames_list) - SEQUENCE_LENGTH + 1, STEP_SIZE):
            seq_paths = frames_list[i : i + SEQUENCE_LENGTH]
            if len(seq_paths) == SEQUENCE_LENGTH:
                seq_id = f"fake_{video_stem}_seq{i//STEP_SIZE}"
                all_sequences_info.append((seq_paths, seq_id, "fake"))

    # --- Step 3: Balance and Compute Flow (Logic is the same) ---
    print("\n--- Step 3: Balancing sequences and preparing for flow computation ---")
    real_sequences = [item for item in all_sequences_info if item[2] == "real"]
    fake_sequences = [item for item in all_sequences_info if item[2] == "fake"]
    min_seq_count = min(len(real_sequences), len(fake_sequences))
    print(f"Balancing to {min_seq_count} sequences per class.")

    random.seed(42)
    real_sequences_sampled = random.sample(real_sequences, min_seq_count)
    fake_sequences_sampled = random.sample(fake_sequences, min_seq_count)

    final_real_sequences = sorted([(item[0], item[1]) for item in real_sequences_sampled], key=lambda x: x[1])
    final_fake_sequences = sorted([(item[0], item[1]) for item in fake_sequences_sampled], key=lambda x: x[1])

    print("\n--- Starting Optical Flow Computation for REAL sequences ---")
    preprocess_and_save_flow(final_real_sequences, DRIVE_OUTPUT_DIR, SEQUENCE_LENGTH)

    gc.collect()

    print("\n--- Starting Optical Flow Computation for FAKE sequences ---")
    preprocess_and_save_flow(final_fake_sequences, DRIVE_OUTPUT_DIR, SEQUENCE_LENGTH)

    print("\n--- Optical Flow Preprocessing is DONE ---")
# Out:
# Mounted at /content/drive
# Precomputed optical flow will be saved to: /content/drive/MyDrive/New_Dataset
# --- Starting Data Subsetting and Optical Flow Preprocessing ---
#
# --- Step 1: Preparing Local Dataset from the first 10 chunks per class ---
#
#   Processing REAL frame chunks...
#   Selected the following 10 chunks to process:
#     - real_frames_chunk_10_090000-099999.zip
#     - real_frames_chunk_11_100000-109999.zip
#     - real_frames_chunk_12_110000-119999.zip
#     - real_frames_chunk_13_120000-129999.zip
#     - real_frames_chunk_14_130000-139999.zip
#     - real_frames_chunk_15_140000-149999.zip
#     - real_frames_chunk_16_150000-159999.zip
#     - real_frames_chunk_17_160000-169999.zip
#     - real_frames_chunk_18_170000-179999.zip
#     - real_frames_chunk_19_180000-189999.zip
#
#   Processing FAKE frame chunks...
#   Selected the following 8 chunks to process:
#     - fake_frames_chunk_12_110000-119999.zip
#     - fake_frames_chunk_13_120000-129999.zip
#     - fake_frames_chunk_14_130000-133999.zip
#     - fake_frames_chunk_15_134000-139899.zip
#     - fake_frames_chunk_16_139900-149899.zip
#     - fake_frames_chunk_17_149900-159899.zip
#     - fake_frames_chunk_18_159900-169899.zip
#     - fake_frames_chunk_19_169900-170199.zip
#
# --- Step 2: Loading frames and creating sequences from the local subset ---
#   Grouped 94060 frames into 1568 video groups for 'real'.
#   Grouped 60200 frames into 1005 video groups for 'fake'.
#
# --- Step 3: Balancing sequences and preparing for flow computation ---
# Balancing to 1910 sequences per class.
#
# --- Starting Optical Flow Computation for REAL sequences ---
# Attempting to generate flow for 1910 sequences...
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g01_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g01_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g01_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g01_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g01_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g01_c06'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g02_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g02_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g02_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g02_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g03_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g03_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g03_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g03_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g03_c06'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g04_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g04_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g04_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g04_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g04_c06'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g04_c07'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g05_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g05_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g05_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g05_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g05_c06'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g05_c07'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g06_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g06_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g06_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g06_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g06_c06'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g07_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g07_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g07_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g07_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g07_c06'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g07_c07'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g08_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g08_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g08_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g09_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g09_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g09_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g09_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g09_c06'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g09_c07'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g10_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g10_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g10_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g10_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g11_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g11_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g11_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g11_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g11_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g12_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g12_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g12_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g12_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g12_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g12_c06'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g13_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g13_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g13_c06'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g14_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g14_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g14_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g14_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g14_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g15_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g15_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g15_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g15_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g15_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g15_c06'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g15_c07'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g16_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g16_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g16_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g16_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g17_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g17_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g17_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g17_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g17_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g18_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g18_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g18_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g18_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g19_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g19_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g19_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g20_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g20_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g20_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g20_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g20_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g20_c06'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g21_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g21_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g21_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g21_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g22_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g22_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g22_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g22_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g23_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g23_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g23_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g23_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g23_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g23_c06'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g24_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g24_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g24_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g24_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g24_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g25_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g25_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g25_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g25_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g25_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g25_c06'
#
#   Now processing sequences from video: 'ucf101_v_ApplyEyeMakeup_g25_c07'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g01_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g01_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g01_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g01_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g02_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g02_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g02_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g03_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g03_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g03_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g03_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g04_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g04_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g04_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g04_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g05_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g05_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g05_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g05_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g05_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g06_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g06_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g06_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g06_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g07_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g07_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g07_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g07_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g08_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g08_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g08_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g08_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g09_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g09_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g10_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g10_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g10_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g11_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g11_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g11_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g11_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g12_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g12_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g12_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g13_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g13_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g13_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g14_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g14_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g14_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g14_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g15_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g15_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g15_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g15_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g16_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g16_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g17_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g17_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g17_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g17_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g17_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g18_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g18_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g18_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g18_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g19_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g19_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g19_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g19_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g20_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g20_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g20_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g20_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g21_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g21_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g21_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g21_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g21_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g22_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g22_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g22_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g22_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g22_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g22_c06'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g22_c07'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g23_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g23_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g23_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g23_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g24_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g24_c04'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g24_c05'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g25_c01'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g25_c02'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g25_c03'
#
#   Now processing sequences from video: 'ucf101_v_ApplyLipstick_g25_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g01_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g01_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g01_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g01_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g01_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g02_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g02_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g02_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g02_c06'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g03_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g03_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g03_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g04_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g04_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g04_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g04_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g05_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g05_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g05_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g06_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g06_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g06_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g06_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g06_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g06_c06'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g07_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g07_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g07_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g07_c06'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g08_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g09_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g09_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g09_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g09_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g09_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g09_c07'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g10_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g10_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g10_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g10_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g10_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g10_c07'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g11_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g11_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g11_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g11_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g11_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g11_c06'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g11_c07'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g12_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g12_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g12_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g12_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g13_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g13_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g13_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g13_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g13_c06'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g13_c07'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g14_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g14_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g14_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g14_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g15_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g15_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g15_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g15_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g15_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g15_c06'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g15_c07'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g16_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g16_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g16_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g17_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g17_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g17_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g18_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g18_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g18_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g18_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g18_c06'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g18_c07'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g19_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g20_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g20_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g20_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g20_c06'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g20_c07'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g21_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g21_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g21_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g21_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g22_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g22_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g22_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g22_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g22_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g23_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g23_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g23_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g23_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g23_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g23_c06'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g24_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g24_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g24_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g24_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g24_c05'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g24_c06'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g25_c01'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g25_c02'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g25_c03'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g25_c04'
#
#   Now processing sequences from video: 'ucf101_v_Archery_g25_c05'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g01_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g01_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g01_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g02_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g02_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g02_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g02_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g02_c06'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g03_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g03_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g04_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g04_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g04_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g05_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g05_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g05_c05'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g06_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g06_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g06_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g06_c05'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g06_c06'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g07_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g07_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g07_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g07_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g07_c05'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g07_c06'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g08_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g08_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g08_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g08_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g09_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g09_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g09_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g09_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g09_c06'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g10_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g10_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g10_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g10_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g10_c05'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g11_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g11_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g11_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g11_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g12_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g12_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g12_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g12_c05'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g12_c06'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g13_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g13_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g13_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g13_c05'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g13_c06'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g14_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g14_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g14_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g14_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g15_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g15_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g15_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g15_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g15_c05'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g15_c06'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g16_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g16_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g16_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g16_c05'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g16_c06'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g17_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g17_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g17_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g17_c05'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g18_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g18_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g18_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g18_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g18_c05'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g18_c06'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g19_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g19_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g19_c05'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g20_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g20_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g20_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g20_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g20_c06'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g20_c07'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g21_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g21_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g21_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g21_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g22_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g22_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g22_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g22_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g22_c05'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g22_c06'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g22_c07'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g23_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g23_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g23_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g24_c01'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g24_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g24_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g24_c05'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g25_c02'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g25_c03'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g25_c04'
#
#   Now processing sequences from video: 'ucf101_v_BabyCrawling_g25_c06'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g01_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g01_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g01_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g01_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g02_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g02_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g02_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g03_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g03_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g03_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g03_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g04_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g04_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g04_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g04_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g05_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g05_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g05_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g05_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g06_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g06_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g06_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g06_c05'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g06_c06'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g06_c07'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g07_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g07_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g07_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g08_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g08_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g08_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g08_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g09_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g09_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g09_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g10_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g10_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g10_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g11_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g11_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g11_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g12_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g12_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g12_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g13_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g13_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g13_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g13_c05'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g14_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g14_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g14_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g14_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g15_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g15_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g15_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g16_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g16_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g16_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g16_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g17_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g17_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g17_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g17_c05'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g17_c06'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g18_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g18_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g18_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g18_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g19_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g19_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g19_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g19_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g20_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g20_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g20_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g21_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g21_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g21_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g21_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g21_c05'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g22_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g22_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g22_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g23_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g23_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g23_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g23_c05'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g24_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g24_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g24_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g24_c04'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g25_c01'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g25_c02'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g25_c03'
#
#   Now processing sequences from video: 'ucf101_v_BalanceBeam_g25_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g01_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g01_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g01_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g01_c05'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g01_c06'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g01_c07'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g02_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g02_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g02_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g02_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g02_c05'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g02_c07'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g03_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g03_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g03_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g03_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g03_c05'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g03_c06'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g03_c07'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g04_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g04_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g04_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g04_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g05_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g05_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g05_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g05_c05'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g05_c06'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g05_c07'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g06_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g06_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g06_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g06_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g07_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g07_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g07_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g07_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g07_c05'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g07_c06'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g07_c07'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g08_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g08_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g08_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g08_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g08_c05'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g08_c06'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g08_c07'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g09_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g09_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g09_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g09_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g09_c05'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g09_c06'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g10_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g10_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g10_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g10_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g10_c06'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g10_c07'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g11_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g11_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g11_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g11_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g11_c05'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g11_c07'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g12_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g12_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g12_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g12_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g12_c05'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g12_c06'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g13_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g13_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g13_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g13_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g13_c05'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g14_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g14_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g14_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g14_c05'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g14_c06'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g15_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g15_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g15_c05'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g15_c06'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g16_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g16_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g16_c05'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g16_c06'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g16_c07'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g17_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g17_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g17_c04'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g18_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g18_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g18_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g18_c05'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g18_c06'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g19_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g19_c05'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g19_c06'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g19_c07'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g20_c01'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g20_c02'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g20_c03'
#
#   Now processing sequences from video: 'ucf101_v_BandMarching_g20_c05'
#
# ...
#
#   Now processing sequences from video: 'VideoPoet_33_b'
#
#   Now processing sequences from video: 'VideoPoet_33_c'
#
#   Now processing sequences from video: 'VideoPoet_33_d'
#
#   Now processing sequences from video: 'VideoPoet_34_a'
#
#   Now processing sequences from video: 'VideoPoet_34_b'
#
#   Now processing sequences from video: 'VideoPoet_34_c'
#
#   Now processing sequences from video: 'VideoPoet_34_d'
#
#   Now processing sequences from video: 'VideoPoet_35_a'
#
#   Now processing sequences from video: 'VideoPoet_35_b'
#
#   Now processing sequences from video: 'VideoPoet_35_c'
#
#   Now processing sequences from video: 'VideoPoet_35_d'
#
#   Now processing sequences from video: 'VideoPoet_36_a'
#
#   Now processing sequences from video: 'VideoPoet_36_b'
#
#   Now processing sequences from video: 'VideoPoet_36_c'
#
#   Now processing sequences from video: 'VideoPoet_36_d'
#
#   Now processing sequences from video: 'VideoPoet_37_a'
#
#   Now processing sequences from video: 'VideoPoet_37_b'
#
#   Now processing sequences from video: 'VideoPoet_37_c'
#
#   Now processing sequences from video: 'VideoPoet_37_d'
#
#   Now processing sequences from video: 'VideoPoet_38_a'
#
#   Now processing sequences from video: 'VideoPoet_38_b'
#
#   Now processing sequences from video: 'VideoPoet_38_c'
#
#   Now processing sequences from video: 'VideoPoet_38_d'
#
#   Now processing sequences from video: 'VideoPoet_39_a'
#
#   Now processing sequences from video: 'VideoPoet_39_b'
#
#   Now processing sequences from video: 'VideoPoet_39_c'
#
#   Now processing sequences from video: 'VideoPoet_39_d'
#
#   Now processing sequences from video: 'VideoPoet_3_a'
#
#   Now processing sequences from video: 'VideoPoet_3_b'
#
#   Now processing sequences from video: 'VideoPoet_3_c'
#
#   Now processing sequences from video: 'VideoPoet_3_d'
#
#   Now processing sequences from video: 'VideoPoet_40_a'
#
#   Now processing sequences from video: 'VideoPoet_40_b'
#
#   Now processing sequences from video: 'VideoPoet_40_c'
#
#   Now processing sequences from video: 'VideoPoet_40_d'
#
#   Now processing sequences from video: 'VideoPoet_41_a'
#
#   Now processing sequences from video: 'VideoPoet_41_b'
#
#   Now processing sequences from video: 'VideoPoet_41_c'
#
#   Now processing sequences from video: 'VideoPoet_41_d'
#
#   Now processing sequences from video: 'VideoPoet_42_a'
#
#   Now processing sequences from video: 'VideoPoet_42_b'
#
#   Now processing sequences from video: 'VideoPoet_42_c'
#
#   Now processing sequences from video: 'VideoPoet_42_d'
#
#   Now processing sequences from video: 'VideoPoet_43_a'
#
#   Now processing sequences from video: 'VideoPoet_43_b'
#
#   Now processing sequences from video: 'VideoPoet_43_c'
#
#   Now processing sequences from video: 'VideoPoet_43_d'
#
#   Now processing sequences from video: 'VideoPoet_44_a'
#
#   Now processing sequences from video: 'VideoPoet_44_b'
#
#   Now processing sequences from video: 'VideoPoet_44_c'
#
#   Now processing sequences from video: 'VideoPoet_44_d'
#
#   Now processing sequences from video: 'VideoPoet_45_a'
#
#   Now processing sequences from video: 'VideoPoet_45_b'
#
#   Now processing sequences from video: 'VideoPoet_45_c'
#
#   Now processing sequences from video: 'VideoPoet_45_d'
#
#   Now processing sequences from video: 'VideoPoet_46_a'
#
#   Now processing sequences from video: 'VideoPoet_46_b'
#
#   Now processing sequences from video: 'VideoPoet_46_c'
#
#   Now processing sequences from video: 'VideoPoet_46_d'
#
#   Now processing sequences from video: 'VideoPoet_47_a'
#
#   Now processing sequences from video: 'VideoPoet_47_b'
#
#   Now processing sequences from video: 'VideoPoet_47_c'
#
#   Now processing sequences from video: 'VideoPoet_47_d'
#
#   Now processing sequences from video: 'VideoPoet_48_a'
#
#   Now processing sequences from video: 'VideoPoet_48_b'
#
#   Now processing sequences from video: 'VideoPoet_48_c'
#
#   Now processing sequences from video: 'VideoPoet_48_d'
#
#   Now processing sequences from video: 'VideoPoet_49_a'
#
#   Now processing sequences from video: 'VideoPoet_49_b'
#
#   Now processing sequences from video: 'VideoPoet_49_c'
#
#   Now processing sequences from video: 'VideoPoet_49_d'
#
#   Now processing sequences from video: 'VideoPoet_4_a'
#
#   Now processing sequences from video: 'VideoPoet_4_b'
#
#   Now processing sequences from video: 'VideoPoet_4_c'
#
#   Now processing sequences from video: 'VideoPoet_4_d'
#
#   Now processing sequences from video: 'VideoPoet_50_a'
#
#   Now processing sequences from video: 'VideoPoet_50_b'
#
#   Now processing sequences from video: 'VideoPoet_50_c'
#
#   Now processing sequences from video: 'VideoPoet_50_d'
#
#   Now processing sequences from video: 'VideoPoet_51_a'
#
#   Now processing sequences from video: 'VideoPoet_51_b'
#
#   Now processing sequences from video: 'VideoPoet_51_c'
#
#   Now processing sequences from video: 'VideoPoet_51_d'
#
#   Now processing sequences from video: 'VideoPoet_52_a'
#
#   Now processing sequences from video: 'VideoPoet_52_b'
#
#   Now processing sequences from video: 'VideoPoet_52_c'
#
#   Now processing sequences from video: 'VideoPoet_52_d'
#
#   Now processing sequences from video: 'VideoPoet_53_a'
#
#   Now processing sequences from video: 'VideoPoet_53_b'
#
#   Now processing sequences from video: 'VideoPoet_53_c'
#
#   Now processing sequences from video: 'VideoPoet_53_d'
#
#   Now processing sequences from video: 'VideoPoet_54_a'
#
#   Now processing sequences from video: 'VideoPoet_54_b'
#
#   Now processing sequences from video: 'VideoPoet_54_c'
#
#   Now processing sequences from video: 'VideoPoet_54_d'
#
#   Now processing sequences from video: 'VideoPoet_55_a'
#
#   Now processing sequences from video: 'VideoPoet_55_b'
#
#   Now processing sequences from video: 'VideoPoet_55_c'
#
#   Now processing sequences from video: 'VideoPoet_55_d'
#
#   Now processing sequences from video: 'VideoPoet_56_a'
#
#   Now processing sequences from video: 'VideoPoet_56_b'
#
#   Now processing sequences from video: 'VideoPoet_56_c'
#
#   Now processing sequences from video: 'VideoPoet_56_d'
#
#   Now processing sequences from video: 'VideoPoet_57_a'
#
#   Now processing sequences from video: 'VideoPoet_57_b'
#
#   Now processing sequences from video: 'VideoPoet_57_c'
#
#   Now processing sequences from video: 'VideoPoet_57_d'
#
#   Now processing sequences from video: 'VideoPoet_58_a'
#
#   Now processing sequences from video: 'VideoPoet_58_b'
#
#   Now processing sequences from video: 'VideoPoet_58_c'
#
#   Now processing sequences from video: 'VideoPoet_58_d'
#
#   Now processing sequences from video: 'VideoPoet_59_a'
#
#   Now processing sequences from video: 'VideoPoet_59_b'
#
#   Now processing sequences from video: 'VideoPoet_59_c'
#
#   Now processing sequences from video: 'VideoPoet_59_d'
#
#   Now processing sequences from video: 'VideoPoet_5_a'
#
#   Now processing sequences from video: 'VideoPoet_5_b'
#
#   Now processing sequences from video: 'VideoPoet_5_c'
#
#   Now processing sequences from video: 'VideoPoet_5_d'
#
#   Now processing sequences from video: 'VideoPoet_60_a'
#
#   Now processing sequences from video: 'VideoPoet_60_b'
#
#   Now processing sequences from video: 'VideoPoet_60_c'
#
#   Now processing sequences from video: 'VideoPoet_60_d'
#
#   Now processing sequences from video: 'VideoPoet_61_a'
#
#   Now processing sequences from video: 'VideoPoet_61_b'
#
#   Now processing sequences from video: 'VideoPoet_61_c'
#
#   Now processing sequences from video: 'VideoPoet_61_d'
#
#   Now processing sequences from video: 'VideoPoet_62_a'
#
#   Now processing sequences from video: 'VideoPoet_62_b'
#
#   Now processing sequences from video: 'VideoPoet_62_c'
#
#   Now processing sequences from video: 'VideoPoet_62_d'
#
#   Now processing sequences from video: 'VideoPoet_63_a'
#
#   Now processing sequences from video: 'VideoPoet_63_b'
#
#   Now processing sequences from video: 'VideoPoet_63_c'
#
#   Now processing sequences from video: 'VideoPoet_63_d'
#
#   Now processing sequences from video: 'VideoPoet_64_a'
#
#   Now processing sequences from video: 'VideoPoet_64_b'
#
#   Now processing sequences from video: 'VideoPoet_64_c'
#
#   Now processing sequences from video: 'VideoPoet_64_d'
#
#   Now processing sequences from video: 'VideoPoet_65_a'
#
#   Now processing sequences from video: 'VideoPoet_65_b'
#
#   Now processing sequences from video: 'VideoPoet_65_c'
#
#   Now processing sequences from video: 'VideoPoet_65_d'
#
#   Now processing sequences from video: 'VideoPoet_66_a'
#
#   Now processing sequences from video: 'VideoPoet_66_b'
#
#   Now processing sequences from video: 'VideoPoet_66_c'
#
#   Now processing sequences from video: 'VideoPoet_66_d'
#
#   Now processing sequences from video: 'VideoPoet_67_a'
#
#   Now processing sequences from video: 'VideoPoet_67_b'
#
#   Now processing sequences from video: 'VideoPoet_67_c'
#
#   Now processing sequences from video: 'VideoPoet_67_d'
#
#   Now processing sequences from video: 'VideoPoet_68_a'
#
#   Now processing sequences from video: 'VideoPoet_68_b'
#
#   Now processing sequences from video: 'VideoPoet_68_c'
#
#   Now processing sequences from video: 'VideoPoet_68_d'
#
#   Now processing sequences from video: 'VideoPoet_69_a'
#
#   Now processing sequences from video: 'VideoPoet_69_b'
#
#   Now processing sequences from video: 'VideoPoet_69_c'
#
#   Now processing sequences from video: 'VideoPoet_69_d'
#
#   Now processing sequences from video: 'VideoPoet_6_a'
#
#   Now processing sequences from video: 'VideoPoet_6_b'
#
#   Now processing sequences from video: 'VideoPoet_6_c'
#
#   Now processing sequences from video: 'VideoPoet_6_d'
#
#   Now processing sequences from video: 'VideoPoet_70_a'
#
#   Now processing sequences from video: 'VideoPoet_70_b'
#
#   Now processing sequences from video: 'VideoPoet_70_c'
#
#   Now processing sequences from video: 'VideoPoet_70_d'
#
#   Now processing sequences from video: 'VideoPoet_71_a'
#
#   Now processing sequences from video: 'VideoPoet_71_b'
#
#   Now processing sequences from video: 'VideoPoet_71_c'
#
#   Now processing sequences from video: 'VideoPoet_71_d'
#
#   Now processing sequences from video: 'VideoPoet_72_a'
#
#   Now processing sequences from video: 'VideoPoet_72_b'
#
#   Now processing sequences from video: 'VideoPoet_72_c'
#
#   Now processing sequences from video: 'VideoPoet_72_d'
#
#   Now processing sequences from video: 'VideoPoet_73_a'
#
#   Now processing sequences from video: 'VideoPoet_73_b'
#
#   Now processing sequences from video: 'VideoPoet_73_c'
#
#   Now processing sequences from video: 'VideoPoet_73_d'
#
#   Now processing sequences from video: 'VideoPoet_74_a'
#
#   Now processing sequences from video: 'VideoPoet_74_b'
#
#   Now processing sequences from video: 'VideoPoet_74_c'
#
#   Now processing sequences from video: 'VideoPoet_74_d'
#
#   Now processing sequences from video: 'VideoPoet_75_a'
#
#   Now processing sequences from video: 'VideoPoet_75_b'
#
#   Now processing sequences from video: 'VideoPoet_75_c'
#
#   Now processing sequences from video: 'VideoPoet_75_d'
#
#   Now processing sequences from video: 'VideoPoet_76_a'
#
#   Now processing sequences from video: 'VideoPoet_76_b'
#
#   Now processing sequences from video: 'VideoPoet_76_c'
#
#   Now processing sequences from video: 'VideoPoet_76_d'
#
#   Now processing sequences from video: 'VideoPoet_77_a'
#
#   Now processing sequences from video: 'VideoPoet_77_b'
#
#   Now processing sequences from video: 'VideoPoet_77_c'
#
#   Now processing sequences from video: 'VideoPoet_77_d'
#
#   Now processing sequences from video: 'VideoPoet_78_a'
#
#   Now processing sequences from video: 'VideoPoet_78_b'
#
#   Now processing sequences from video: 'VideoPoet_78_c'
#
#   Now processing sequences from video: 'VideoPoet_78_d'
#
#   Now processing sequences from video: 'VideoPoet_79_a'
#
#   Now processing sequences from video: 'VideoPoet_79_b'
#
#   Now processing sequences from video: 'VideoPoet_79_c'
#
#   Now processing sequences from video: 'VideoPoet_79_d'
#
#   Now processing sequences from video: 'VideoPoet_7_a'
#
#   Now processing sequences from video: 'VideoPoet_7_b'
#
#   Now processing sequences from video: 'VideoPoet_7_c'
#
#   Now processing sequences from video: 'VideoPoet_7_d'
#
#   Now processing sequences from video: 'VideoPoet_80_a'
#
#   Now processing sequences from video: 'VideoPoet_80_b'
#
#   Now processing sequences from video: 'VideoPoet_80_c'
#
#   Now processing sequences from video: 'VideoPoet_80_d'
#
#   Now processing sequences from video: 'VideoPoet_81_a'
#
#   Now processing sequences from video: 'VideoPoet_81_b'
#
#   Now processing sequences from video: 'VideoPoet_81_c'
#
#   Now processing sequences from video: 'VideoPoet_81_d'
#
#   Now processing sequences from video: 'VideoPoet_82_a'
#
#   Now processing sequences from video: 'VideoPoet_82_b'
#
#   Now processing sequences from video: 'VideoPoet_82_c'
#
#   Now processing sequences from video: 'VideoPoet_82_d'
#
#   Now processing sequences from video: 'VideoPoet_83_a'
#
#   Now processing sequences from video: 'VideoPoet_83_b'
#
#   Now processing sequences from video: 'VideoPoet_83_c'
#
#   Now processing sequences from video: 'VideoPoet_83_d'
#
#   Now processing sequences from video: 'VideoPoet_84_a'
#
#   Now processing sequences from video: 'VideoPoet_84_b'
#
#   Now processing sequences from video: 'VideoPoet_84_c'
#
#   Now processing sequences from video: 'VideoPoet_84_d'
#
#   Now processing sequences from video: 'VideoPoet_85_a'
#
#   Now processing sequences from video: 'VideoPoet_85_b'
#
#   Now processing sequences from video: 'VideoPoet_85_c'
#
#   Now processing sequences from video: 'VideoPoet_85_d'
#
#   Now processing sequences from video: 'VideoPoet_86_a'
#
#   Now processing sequences from video: 'VideoPoet_86_b'
#
#   Now processing sequences from video: 'VideoPoet_86_c'
#
#   Now processing sequences from video: 'VideoPoet_86_d'
#
#   Now processing sequences from video: 'VideoPoet_87_a'
#
#   Now processing sequences from video: 'VideoPoet_87_b'
#
#   Now processing sequences from video: 'VideoPoet_87_c'
#
#   Now processing sequences from video: 'VideoPoet_87_d'
#
#   Now processing sequences from video: 'VideoPoet_88_a'
#
#   Now processing sequences from video: 'VideoPoet_88_b'
#
#   Now processing sequences from video: 'VideoPoet_88_c'
#
#   Now processing sequences from video: 'VideoPoet_88_d'
#
#   Now processing sequences from video: 'VideoPoet_89_a'
#
#   Now processing sequences from video: 'VideoPoet_89_b'
#
#   Now processing sequences from video: 'VideoPoet_89_c'
#
#   Now processing sequences from video: 'VideoPoet_89_d'
#
#   Now processing sequences from video: 'VideoPoet_8_a'
#
#   Now processing sequences from video: 'VideoPoet_8_b'
#
#   Now processing sequences from video: 'VideoPoet_8_c'
#
#   Now processing sequences from video: 'VideoPoet_8_d'
#
#   Now processing sequences from video: 'VideoPoet_90_a'
#
#   Now processing sequences from video: 'VideoPoet_90_b'
#
#   Now processing sequences from video: 'VideoPoet_90_c'
#
#   Now processing sequences from video: 'VideoPoet_90_d'
#
#   Now processing sequences from video: 'VideoPoet_91_a'
#
#   Now processing sequences from video: 'VideoPoet_91_b'
#
#   Now processing sequences from video: 'VideoPoet_91_c'
#
#   Now processing sequences from video: 'VideoPoet_91_d'
#
#   Now processing sequences from video: 'VideoPoet_92_a'
#
#   Now processing sequences from video: 'VideoPoet_92_b'
#
#   Now processing sequences from video: 'VideoPoet_92_c'
#
#   Now processing sequences from video: 'VideoPoet_92_d'
#
#   Now processing sequences from video: 'VideoPoet_93_a'
#
#   Now processing sequences from video: 'VideoPoet_93_b'
#
#   Now processing sequences from video: 'VideoPoet_93_c'
#
#   Now processing sequences from video: 'VideoPoet_93_d'
#
#   Now processing sequences from video: 'VideoPoet_94_a'
#
#   Now processing sequences from video: 'VideoPoet_94_b'
#
#   Now processing sequences from video: 'VideoPoet_94_c'
#
#   Now processing sequences from video: 'VideoPoet_94_d'
#
#   Now processing sequences from video: 'VideoPoet_99_a'
#
#   Now processing sequences from video: 'VideoPoet_99_b'
#
#   Now processing sequences from video: 'VideoPoet_99_c'
#
#   Now processing sequences from video: 'VideoPoet_99_d'
#
#   Now processing sequences from video: 'VideoPoet_9_a'
#
#   Now processing sequences from video: 'VideoPoet_9_b'
#
#   Now processing sequences from video: 'VideoPoet_9_c'
#
#   Now processing sequences from video: 'VideoPoet_9_d'
# --- Finished precomputing. Generated 1910 new flow sequences. ---
#
# --- Optical Flow Preprocessing is DONE ---

# %% [markdown]
# Adding New Flow to Old Flow File

# %%
# === SCRIPT TO RECOMBINE, FLATTEN, AND RE-ZIP OLD AND NEW FLOW FILES ===

import os
import glob
import time
import shutil
import zipfile
from pathlib import Path
from google.colab import drive

# --- Configuration ---
# 1. Path to your OLD flow zip file
DRIVE_OLD_FLOW_ZIP_PATH = "/content/drive/MyDrive/Old_Flow_Might_Use/precomputed_flow30_SS30.zip"

# 2. Path to your NEW flow zip file
DRIVE_NEW_FLOW_ZIP_PATH = "/content/drive/MyDrive/New_Dataset/new_precomputed_flow.zip"

# 3. The destination on Drive for the FINAL MERGED zip file
DRIVE_FINAL_OUTPUT_DIR = "/content/drive/MyDrive/zipped"

# 4. The name for the final, combined zip file
FINAL_ZIP_NAME = "Combined_Precomputed_Flow.zip"

# 5. Temporary local directories
LOCAL_TEMP_ZIPS_DIR = "/content/temp_zips_for_recombine"
LOCAL_TEMP_UNZIPPED_DIR = "/content/temp_unzipped_for_recombine"
LOCAL_FINAL_MERGED_DIR = "/content/Final_Combined_Flow"
# --- End of Configuration ---


# --- Main Logic ---
print("--- Starting Robust Re-Combination Process for Flow Files ---")
drive.mount('/content/drive', force_remount=True)

final_zip_path_on_drive = os.path.join(DRIVE_FINAL_OUTPUT_DIR, FINAL_ZIP_NAME)

# --- Pre-computation Check ---
# Ask to delete the old file if it exists, to ensure a fresh start.
if os.path.exists(final_zip_path_on_drive):
    print(f"\nWARNING: The destination file '{FINAL_ZIP_NAME}' already exists.")
    user_input = input("Do you want to delete it and re-create it? (yes/no): ")
    if user_input.lower() == 'yes':
        print(f"Deleting old file: {final_zip_path_on_drive}")
        os.remove(final_zip_path_on_drive)
    else:
        print("Operation cancelled by user. Exiting.")
        import sys; sys.exit()

# --- Step 1: Create local directories ---
os.makedirs(LOCAL_TEMP_ZIPS_DIR, exist_ok=True)
os.makedirs(LOCAL_TEMP_UNZIPPED_DIR, exist_ok=True)
os.makedirs(LOCAL_FINAL_MERGED_DIR, exist_ok=True)


# --- Step 2: Copy both source zips locally ---
print("\n--- Step 2: Copying source zip files locally... ---")
# ... (Same copy logic as before) ...
source_zips = [DRIVE_OLD_FLOW_ZIP_PATH, DRIVE_NEW_FLOW_ZIP_PATH]
copied_zips = []
for path in source_zips:
    if os.path.exists(path):
        shutil.copy(path, LOCAL_TEMP_ZIPS_DIR)
        copied_zips.append(os.path.join(LOCAL_TEMP_ZIPS_DIR, Path(path).name))


# --- Step 3: Unzip SEPARATELY and then Consolidate ---
print(f"\n--- Step 3: Unzipping, finding, and consolidating all .pt files... ---")
all_found_pt_files = []
for zip_file_path in copied_zips:
    model_name = Path(zip_file_path).stem
    temp_extract_path = os.path.join(LOCAL_TEMP_UNZIPPED_DIR, model_name)
    os.makedirs(temp_extract_path, exist_ok=True)

    print(f"  Unzipping '{Path(zip_file_path).name}' into a temporary folder...")
    # !unzip -q -o "{zip_file_path}" -d "{temp_extract_path}"

    # Recursively find all .pt files inside this specific extraction
    search_pattern = os.path.join(temp_extract_path, '**', '*.pt')
    found_files = glob.glob(search_pattern, recursive=True)
    print(f"    -> Found {len(found_files):,} files in this archive.")
    all_found_pt_files.extend(found_files)

# Now, move all found files into the single, flat, final directory
print("\n  Moving all found files into the final consolidated directory...")
for file_path in all_found_pt_files:
    shutil.move(file_path, LOCAL_FINAL_MERGED_DIR)

# --- Step 4: Verify the consolidated folder ---
print("\n--- Step 4: Verifying the final merged folder... ---")
final_file_count = len(glob.glob(os.path.join(LOCAL_FINAL_MERGED_DIR, '*.pt')))
print("\n==============================================")
print(f"  ✅ VERIFICATION COMPLETE")
print(f"  Total files in the consolidated folder: {final_file_count:,}")
print("==============================================")
if final_file_count < 9000: # Sanity check
    print("WARNING: Final count is lower than expected. Please check the source zips.")


# --- Step 5: Zip the final, clean, consolidated folder ---
print(f"\n--- Step 5: Creating the final merged zip file '{FINAL_ZIP_NAME}'... ---")
local_final_zip_path = f"/content/{FINAL_ZIP_NAME}"
with zipfile.ZipFile(local_final_zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for file in os.listdir(LOCAL_FINAL_MERGED_DIR):
        zipf.write(os.path.join(LOCAL_FINAL_MERGED_DIR, file), arcname=file)
print("-> Final zip file created.")


# --- Step 6: Upload the final zip to Google Drive ---
print(f"\n--- Step 6: Uploading '{FINAL_ZIP_NAME}' to Google Drive... ---")
shutil.move(local_final_zip_path, final_zip_path_on_drive)
print("-> Upload complete.")


# --- Step 7: Final Cleanup ---
print("\n--- Step 7: Cleaning up all temporary local files... ---")
shutil.rmtree(LOCAL_TEMP_ZIPS_DIR, ignore_errors=True)
shutil.rmtree(LOCAL_TEMP_UNZIPPED_DIR, ignore_errors=True)
shutil.rmtree(LOCAL_FINAL_MERGED_DIR, ignore_errors=True)

print(f"\n\n--- Process finished successfully! ---")
print(f"✅ Your new, clean, and complete flow archive is saved at: '{final_zip_path_on_drive}'")
# Out:
# --- Starting Robust Re-Combination Process for Flow Files ---
# Mounted at /content/drive
#
# --- Step 2: Copying source zip files locally... ---
#
# --- Step 3: Unzipping, finding, and consolidating all .pt files... ---
#   Unzipping 'precomputed_flow30_SS30.zip' into a temporary folder...
#     -> Found 5,452 files in this archive.
#   Unzipping 'new_precomputed_flow.zip' into a temporary folder...
#     -> Found 3,820 files in this archive.
#
#   Moving all found files into the final consolidated directory...
#
# --- Step 4: Verifying the final merged folder... ---
#
# ==============================================
#   ✅ VERIFICATION COMPLETE
#   Total files in the consolidated folder: 9,272
# ==============================================
#
# --- Step 5: Creating the final merged zip file 'Combined_Precomputed_Flow.zip'... ---
# -> Final zip file created.
#
# --- Step 6: Uploading 'Combined_Precomputed_Flow.zip' to Google Drive... ---
# -> Upload complete.
#
# --- Step 7: Cleaning up all temporary local files... ---
#
#
# --- Process finished successfully! ---
# ✅ Your new, clean, and complete flow archive is saved at: '/content/drive/MyDrive/zipped/Combined_Precomputed_Flow.zip'

# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.34.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.1.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2025.8.3)

# %%
# === CROSS-DATASET PREPROCESSING: REAL + FAKE (FRAMES + FLOW, SEPARATE ZIPS) ===
import os
import cv2
import numpy as np
import torch
import random
import glob
import zipfile
import shutil
from pathlib import Path
from google.colab import drive

# --- Config ---
DRIVE_REAL_ZIP = "/content/drive/MyDrive/Test_Dataset/Real/Real.zip"
DRIVE_FAKE_ZIP = "/content/drive/MyDrive/Test_Dataset/Fake/Fake.zip"
LOCAL_REAL_DIR = "/content/Real_Unzipped"
LOCAL_FAKE_DIR = "/content/Fake_Unzipped"

OUTPUT_FRAMES_DIR = "/content/Frames_Output"
OUTPUT_FLOW_DIR = "/content/Flow_Output"

FINAL_REAL_FRAMES_ZIP = "/content/drive/MyDrive/Test_Dataset/Real/Frames_Real.zip"
FINAL_FAKE_FRAMES_ZIP = "/content/drive/MyDrive/Test_Dataset/Fake/Frames_Fake.zip"
FINAL_REAL_FLOW_ZIP   = "/content/drive/MyDrive/Test_Dataset/Real/Flow_Real.zip"
FINAL_FAKE_FLOW_ZIP   = "/content/drive/MyDrive/Test_Dataset/Fake/Flow_Fake.zip"

NUM_VIDEOS = 250
FRAMES_PER_VIDEO = 60
SEQ_LENGTH = 30
STEP_SIZE = 30

# --- Mount Drive ---
drive.mount('/content/drive', force_remount=True)

# --- Prepare Output Dirs ---
shutil.rmtree(OUTPUT_FRAMES_DIR, ignore_errors=True)
shutil.rmtree(OUTPUT_FLOW_DIR, ignore_errors=True)
os.makedirs(os.path.join(OUTPUT_FRAMES_DIR, "Real"), exist_ok=True)
os.makedirs(os.path.join(OUTPUT_FRAMES_DIR, "Fake"), exist_ok=True)
os.makedirs(os.path.join(OUTPUT_FLOW_DIR, "Real"), exist_ok=True)
os.makedirs(os.path.join(OUTPUT_FLOW_DIR, "Fake"), exist_ok=True)

# --- Helper: Unzip dataset ---
def unzip_to_local(zip_path, extract_dir):
    if not os.path.exists(extract_dir):
        os.makedirs(extract_dir, exist_ok=True)
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(extract_dir)
        print(f"✅ Extracted {zip_path} to {extract_dir}")
    else:
        print(f"ℹ️ Using existing extracted folder: {extract_dir}")

# --- Helper: Extract frames ---
def extract_and_save_frames(video_path, save_folder, num_frames=60):
    os.makedirs(save_folder, exist_ok=True)
    cap = cv2.VideoCapture(video_path)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if frame_count <= 0:
        cap.release()
        return []

    indices = np.linspace(0, frame_count - 1, num=num_frames, dtype=int)
    saved_paths = []
    for idx_i, idx in enumerate(indices):
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if not ret:
            continue
        frame_name = f"{Path(video_path).stem}_frame_{idx_i:03d}.jpg"
        frame_path = os.path.join(save_folder, frame_name)
        cv2.imwrite(frame_path, frame)
        saved_paths.append(frame_path)
    cap.release()
    return saved_paths

# --- Helper: Optical Flow ---
def compute_optical_flow(frames):
    flows = [np.array([0.0, 0.0], dtype=np.float32)]
    for i in range(len(frames) - 1):
        prev_gray = cv2.cvtColor(frames[i], cv2.COLOR_BGR2GRAY)
        next_gray = cv2.cvtColor(frames[i+1], cv2.COLOR_BGR2GRAY)
        flow_cv = cv2.calcOpticalFlowFarneback(prev_gray, next_gray, None,
                                               0.5, 3, 15, 3, 5, 1.2, 0)
        mag = np.sqrt(flow_cv[..., 0]**2 + flow_cv[..., 1]**2)
        flows.append(np.array([np.mean(mag), np.var(mag)], dtype=np.float32))
    return torch.tensor(np.array(flows), dtype=torch.float32)

# --- Process videos (Real or Fake) ---
def process_videos(extract_dir, label):
    video_paths = sorted(glob.glob(os.path.join(extract_dir, "**", "*.mp4"), recursive=True))
    selected = random.sample(video_paths, min(NUM_VIDEOS, len(video_paths)))
    print(f"Processing {len(selected)} {label} videos...")

    for vid_idx, vid_path in enumerate(selected):
        vid_name = Path(vid_path).stem
        frame_save_dir = os.path.join(OUTPUT_FRAMES_DIR, label, vid_name)
        frame_paths = extract_and_save_frames(vid_path, frame_save_dir, FRAMES_PER_VIDEO)

        if len(frame_paths) < FRAMES_PER_VIDEO:
            print(f"⚠️ Skipping {vid_name}, not enough frames.")
            continue

        # Load frames for flow
        frames = [cv2.imread(fp) for fp in frame_paths]

        # 30-frame sequences
        for i in range(0, len(frames) - SEQ_LENGTH + 1, STEP_SIZE):
            seq_frames = frames[i:i+SEQ_LENGTH]
            if len(seq_frames) == SEQ_LENGTH:
                flow_tensor = compute_optical_flow(seq_frames)
                save_name = f"{label.lower()}_{vid_name}_seq{i//STEP_SIZE}.pt"
                save_path = os.path.join(OUTPUT_FLOW_DIR, label, save_name)
                torch.save(flow_tensor, save_path)

        if (vid_idx + 1) % 20 == 0:
            print(f"  Processed {vid_idx+1}/{len(selected)} {label} videos")

# --- Main ---
print("=== Starting Preprocessing for Real + Fake Videos ===")
unzip_to_local(DRIVE_REAL_ZIP, LOCAL_REAL_DIR)
unzip_to_local(DRIVE_FAKE_ZIP, LOCAL_FAKE_DIR)

process_videos(LOCAL_REAL_DIR, "Real")
process_videos(LOCAL_FAKE_DIR, "Fake")

# --- Zip frames and flow separately ---
shutil.make_archive("/content/Frames_Real", 'zip', os.path.join(OUTPUT_FRAMES_DIR, "Real"))
shutil.make_archive("/content/Frames_Fake", 'zip', os.path.join(OUTPUT_FRAMES_DIR, "Fake"))
shutil.make_archive("/content/Flow_Real", 'zip', os.path.join(OUTPUT_FLOW_DIR, "Real"))
shutil.make_archive("/content/Flow_Fake", 'zip', os.path.join(OUTPUT_FLOW_DIR, "Fake"))

# --- Move zips to Drive ---
shutil.move("/content/Frames_Real.zip", FINAL_REAL_FRAMES_ZIP)
shutil.move("/content/Frames_Fake.zip", FINAL_FAKE_FRAMES_ZIP)
shutil.move("/content/Flow_Real.zip", FINAL_REAL_FLOW_ZIP)
shutil.move("/content/Flow_Fake.zip", FINAL_FAKE_FLOW_ZIP)

print("✅ Done! Saved zips to Drive:")
print("   ", FINAL_REAL_FRAMES_ZIP)
print("   ", FINAL_FAKE_FRAMES_ZIP)
print("   ", FINAL_REAL_FLOW_ZIP)
print("   ", FINAL_FAKE_FLOW_ZIP)
# Out:
# Mounted at /content/drive
# === Starting Preprocessing for Real + Fake Videos ===
# ℹ️ Using existing extracted folder: /content/Real_Unzipped
# ℹ️ Using existing extracted folder: /content/Fake_Unzipped
# Processing 250 Real videos...
#   Processed 20/250 Real videos
#   Processed 40/250 Real videos
#   Processed 60/250 Real videos
#   Processed 80/250 Real videos
#   Processed 100/250 Real videos
#   Processed 120/250 Real videos
#   Processed 140/250 Real videos
#   Processed 160/250 Real videos
#   Processed 180/250 Real videos
#   Processed 200/250 Real videos
#   Processed 220/250 Real videos
#   Processed 240/250 Real videos
# Processing 250 Fake videos...
#   Processed 20/250 Fake videos
#   Processed 40/250 Fake videos
#   Processed 60/250 Fake videos
#   Processed 80/250 Fake videos
#   Processed 100/250 Fake videos
#   Processed 120/250 Fake videos
#   Processed 140/250 Fake videos
#   Processed 160/250 Fake videos
#   Processed 180/250 Fake videos
#   Processed 200/250 Fake videos
#   Processed 220/250 Fake videos
#   Processed 240/250 Fake videos
# ✅ Done! Saved zips to Drive:
#     /content/drive/MyDrive/Test_Dataset/Real/Frames_Real.zip
#     /content/drive/MyDrive/Test_Dataset/Fake/Frames_Fake.zip
#     /content/drive/MyDrive/Test_Dataset/Real/Flow_Real.zip
#     /content/drive/MyDrive/Test_Dataset/Fake/Flow_Fake.zip

# %%
import os
import cv2
import numpy as np
import torch
import random
import glob
import zipfile
import shutil
from pathlib import Path
from google.colab import drive

# --- Config ---
DRIVE_FAKE_ZIP = "/content/drive/MyDrive/Test_Dataset/Fake/Fake.zip"
LOCAL_FAKE_DIR = "/content/Fake_Unzipped"

OUTPUT_FRAMES_DIR = "/content/Frames_Output/Fake"
OUTPUT_FLOW_DIR = "/content/Flow_Output/Fake"

FINAL_FAKE_FRAMES_ZIP = "/content/drive/MyDrive/Test_Dataset/Fake/Frames_Fake.zip"
FINAL_FAKE_FLOW_ZIP   = "/content/drive/MyDrive/Test_Dataset/Fake/Flow_Fake.zip"

NUM_VIDEOS = 250
FRAMES_PER_VIDEO = 60
SEQ_LENGTH = 30
STEP_SIZE = 30

# --- Mount Drive ---
drive.mount('/content/drive', force_remount=True)

# --- Prepare Output Dirs ---
shutil.rmtree(OUTPUT_FRAMES_DIR, ignore_errors=True)
shutil.rmtree(OUTPUT_FLOW_DIR, ignore_errors=True)
os.makedirs(OUTPUT_FRAMES_DIR, exist_ok=True)
os.makedirs(OUTPUT_FLOW_DIR, exist_ok=True)

# --- Helper: Unzip dataset ---
def unzip_to_local(zip_path, extract_dir):
    if not os.path.exists(extract_dir):
        os.makedirs(extract_dir, exist_ok=True)
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(extract_dir)
        print(f"✅ Extracted {zip_path} to {extract_dir}")
    else:
        print(f"ℹ️ Using existing extracted folder: {extract_dir}")

# --- Helper: Extract frames ---
def extract_and_save_frames(video_path, save_folder, num_frames=60):
    os.makedirs(save_folder, exist_ok=True)
    cap = cv2.VideoCapture(video_path)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if frame_count <= 0:
        cap.release()
        return []

    indices = np.linspace(0, frame_count - 1, num=num_frames, dtype=int)
    saved_paths = []
    for idx_i, idx in enumerate(indices):
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if not ret:
            continue
        frame_name = f"{Path(video_path).stem}_frame_{idx_i:03d}.jpg"
        frame_path = os.path.join(save_folder, frame_name)
        cv2.imwrite(frame_path, frame)
        saved_paths.append(frame_path)
    cap.release()
    return saved_paths

# --- Helper: Optical Flow ---
def compute_optical_flow(frames):
    flows = [np.array([0.0, 0.0], dtype=np.float32)]
    for i in range(len(frames) - 1):
        prev_gray = cv2.cvtColor(frames[i], cv2.COLOR_BGR2GRAY)
        next_gray = cv2.cvtColor(frames[i+1], cv2.COLOR_BGR2GRAY)
        flow_cv = cv2.calcOpticalFlowFarneback(prev_gray, next_gray, None,
                                               0.5, 3, 15, 3, 5, 1.2, 0)
        mag = np.sqrt(flow_cv[..., 0]**2 + flow_cv[..., 1]**2)
        flows.append(np.array([np.mean(mag), np.var(mag)], dtype=np.float32))
    return torch.tensor(np.array(flows), dtype=torch.float32)

# --- Process videos ---
def process_fake_videos(extract_dir):
    video_paths = sorted(glob.glob(os.path.join(extract_dir, "**", "*.mp4"), recursive=True))
    selected = random.sample(video_paths, min(NUM_VIDEOS, len(video_paths)))
    print(f"Processing {len(selected)} Fake videos...")

    for vid_idx, vid_path in enumerate(selected):
        vid_name = Path(vid_path).stem
        # Make unique name for each video
        unique_vid_name = f"{vid_idx:03d}_{vid_name}"

        frame_save_dir = os.path.join(OUTPUT_FRAMES_DIR, unique_vid_name)
        frame_paths = extract_and_save_frames(vid_path, frame_save_dir, FRAMES_PER_VIDEO)

        if len(frame_paths) < FRAMES_PER_VIDEO:
            print(f"⚠️ Skipping {unique_vid_name}, not enough frames.")
            continue

        frames = [cv2.imread(fp) for fp in frame_paths]

        for i in range(0, len(frames) - SEQ_LENGTH + 1, STEP_SIZE):
            seq_frames = frames[i:i+SEQ_LENGTH]
            if len(seq_frames) == SEQ_LENGTH:
                flow_tensor = compute_optical_flow(seq_frames)
                save_name = f"fake_{unique_vid_name}_seq{i//STEP_SIZE}.pt"
                save_path = os.path.join(OUTPUT_FLOW_DIR, save_name)
                torch.save(flow_tensor, save_path)

        if (vid_idx + 1) % 20 == 0:
            print(f"  Processed {vid_idx+1}/{len(selected)} Fake videos")

# --- Main ---
print("=== Starting Preprocessing for Fake Videos ===")
unzip_to_local(DRIVE_FAKE_ZIP, LOCAL_FAKE_DIR)
process_fake_videos(LOCAL_FAKE_DIR)

# --- Zip frames and flow separately ---
shutil.make_archive("/content/Frames_Fake", 'zip', OUTPUT_FRAMES_DIR)
shutil.make_archive("/content/Flow_Fake", 'zip', OUTPUT_FLOW_DIR)

# --- Move zips to Drive ---
shutil.move("/content/Frames_Fake.zip", FINAL_FAKE_FRAMES_ZIP)
shutil.move("/content/Flow_Fake.zip", FINAL_FAKE_FLOW_ZIP)

print("✅ Done! Saved zips to Drive:")
print("   ", FINAL_FAKE_FRAMES_ZIP)
print("   ", FINAL_FAKE_FLOW_ZIP)
# Out:
# Mounted at /content/drive
# === Starting Preprocessing for Fake Videos ===
# ✅ Extracted /content/drive/MyDrive/Test_Dataset/Fake/Fake.zip to /content/Fake_Unzipped
# Processing 250 Fake videos...
#   Processed 20/250 Fake videos
#   Processed 40/250 Fake videos
#   Processed 60/250 Fake videos
#   Processed 80/250 Fake videos
#   Processed 100/250 Fake videos
#   Processed 120/250 Fake videos
#   Processed 140/250 Fake videos
#   Processed 160/250 Fake videos
#   Processed 180/250 Fake videos
#   Processed 200/250 Fake videos
#   Processed 220/250 Fake videos
#   Processed 240/250 Fake videos
# ✅ Done! Saved zips to Drive:
#     /content/drive/MyDrive/Test_Dataset/Fake/Frames_Fake.zip
#     /content/drive/MyDrive/Test_Dataset/Fake/Flow_Fake.zip
